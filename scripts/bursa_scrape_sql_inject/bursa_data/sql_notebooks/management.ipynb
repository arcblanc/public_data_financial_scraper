# %%
import pandas as pd

# %%
csv = pd.read_csv("../combined_management.csv",keep_default_na=True,na_values=["None", "none", "NaN", "-"],low_memory=False,dtype={"company_id": str})
csv["company_id"] = csv["company_id"].astype(str)
csv.head()
# Out:
#   company_id                                        company_url  \
# 0      03050  https://my.bursamalaysia.com/stock-details?sto...
# 1      03050  https://my.bursamalaysia.com/stock-details?sto...
# 2       5238  https://my.bursamalaysia.com/stock-details?sto...
# 3       5238  https://my.bursamalaysia.com/stock-details?sto...
# 4       5238  https://my.bursamalaysia.com/stock-details?sto...
#
#                       Name                   Designation     Role   Since
# 0                      NaN                           NaN      NaN     NaN
# 1                      NaN                           NaN      NaN     NaN
# 2  Mr. Benyamin Bin Ismail       Chief Executive Officer  Officer     NaN
# 3        Ms. Lavinia Louis       Chief Financial Officer  Officer  2023.0
# 4      Capt. Suresh Bangah  Director - Flight Operations  Officer  2013.0

# %%
df = csv
bad_ids = df[~df["company_id"].str.fullmatch(r"\d{4}")]
print("Bad company_ids:")
print(bad_ids['company_id'])
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 1800    03008
# 1933    03053
# 1934    03053
# 1935    03053
# 1936    03053
# 1937    03053
# 1938    03053
# 1939    03053
# 1940    03053
# 1941    03053
# 1942    03053
# 1943    03053
# 1944    03053
# 1945    03053
# 1946    03053
# 1947    03053
# 1948    03053
# 1949    03053
# 1950    03053
# 1951    03053
# 2260    03021
# 2261    03021
# 3203    03022
# 3225    03041
# 3322    03046
# Name: company_id, dtype: object

# %%
# Ensure company_id is string
csv["company_id"] = csv["company_id"].astype(str)

# Detect bad IDs (not exactly 4 digits)
bad_mask = ~csv["company_id"].str.fullmatch(r"\d{4}")

# Print them
print("Bad company_ids:")
print(csv.loc[bad_mask, "company_id"])

# Fix only the bad ones
csv.loc[bad_mask, "company_id"] = csv.loc[bad_mask, "company_id"].str.zfill(4)
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 1800    03008
# 1933    03053
# 1934    03053
# 1935    03053
# 1936    03053
# 1937    03053
# 1938    03053
# 1939    03053
# 1940    03053
# 1941    03053
# 1942    03053
# 1943    03053
# 1944    03053
# 1945    03053
# 1946    03053
# 1947    03053
# 1948    03053
# 1949    03053
# 1950    03053
# 1951    03053
# 2260    03021
# 2261    03021
# 3203    03022
# 3225    03041
# 3322    03046
# Name: company_id, dtype: object

# %%
# Ensure company_id is string type
csv["company_id"] = csv["company_id"].astype(str)

# Find malformed IDs that are not 4-digit strings
bad_ids = csv[~csv["company_id"].str.fullmatch(r"\d{4}")]

# Report bad IDs
print("Bad company_ids:")
print(bad_ids["company_id"])
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 1800    03008
# 1933    03053
# 1934    03053
# 1935    03053
# 1936    03053
# 1937    03053
# 1938    03053
# 1939    03053
# 1940    03053
# 1941    03053
# 1942    03053
# 1943    03053
# 1944    03053
# 1945    03053
# 1946    03053
# 1947    03053
# 1948    03053
# 1949    03053
# 1950    03053
# 1951    03053
# 2260    03021
# 2261    03021
# 3203    03022
# 3225    03041
# 3322    03046
# Name: company_id, dtype: object

# %%
csv["company_id"].nunique()
# Out:
# 172

# %%
df = csv

# %%
merged = df

# %%
len(merged.columns)
# Out:
# 6

# %%
merged
# Out:
#      company_id                                        company_url  \
# 0         03050  https://my.bursamalaysia.com/stock-details?sto...
# 1         03050  https://my.bursamalaysia.com/stock-details?sto...
# 2          5238  https://my.bursamalaysia.com/stock-details?sto...
# 3          5238  https://my.bursamalaysia.com/stock-details?sto...
# 4          5238  https://my.bursamalaysia.com/stock-details?sto...
# ...         ...                                                ...
# 3465       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3466       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3467       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3468       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3469       3905  https://my.bursamalaysia.com/stock-details?sto...
#
#                          Name                             Designation  \
# 0                         NaN                                     NaN
# 1                         NaN                                     NaN
# 2     Mr. Benyamin Bin Ismail                 Chief Executive Officer
# 3           Ms. Lavinia Louis                 Chief Financial Officer
# 4         Capt. Suresh Bangah            Director - Flight Operations
# ...                       ...                                     ...
# 3465        Mr. Hoy Ping Chew  Non-Independent Non-Executive Director
# 3466                      NaN                                     NaN
# 3467                      NaN                                     NaN
# 3468                      NaN                                     NaN
# 3469                      NaN                                     NaN
#
#           Role   Since
# 0          NaN     NaN
# 1          NaN     NaN
# 2      Officer     NaN
# 3      Officer  2023.0
# 4      Officer  2013.0
# ...        ...     ...
# 3465  Director  2023.0
# 3466       NaN     NaN
# 3467       NaN     NaN
# 3468       NaN     NaN
# 3469       NaN     NaN
#
# [3470 rows x 6 columns]

# %%
bursa_registration = pd.read_csv("../matched_companies_from_ssm.csv",dtype={"company_id": str,"companyNo": str})
bursa_registration["companyNo"] = (
    bursa_registration["companyNo"]
    .astype(str)
    .str.replace(r"\.0$", "", regex=True)
    .str.strip()
)
bursa_registration.head()
# Out:
#                            company_name                               name_db  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD     7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1  99 SPEED MART RETAIL HOLDINGS BERHAD  99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                         A-RANK BERHAD           A-RANK ASSOCIATES SDN. BHD.
# 3                    ABLE GLOBAL BERHAD          ABLE GLOBAL (MM2H) SDN. BHD.
# 4                      ABLEGROUP BERHAD                      ABLEGROUP BERHAD
#
#         companyNo oldCompanyNo company_type
# 0  201301028701.0    1058531-W      Company
# 1  202301017784.0    1511706-T      Company
# 2  199701029773.0     445272-P      Company
# 3  199501013751.0     342952-P      Company
# 4  200401015685.0     654188-H      Company

# %%
company_id = pd.read_csv("../../../list_bursa_ids/bursa_company_list.csv", dtype={"company_id": str})
company_id["company_id"] = company_id["company_id"].str.strip().str.zfill(4)

# %%
merge = pd.merge(bursa_registration,company_id,on="company_name",how="inner")
merge
# Out:
#                               company_name  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                                    name_db       companyNo oldCompanyNo  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD  201301028701.0    1058531-W
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD  202301017784.0    1511706-T
# 2              A-RANK ASSOCIATES SDN. BHD.  199701029773.0     445272-P
# 3             ABLE GLOBAL (MM2H) SDN. BHD.  199501013751.0     342952-P
# 4                         ABLEGROUP BERHAD  200401015685.0     654188-H
# ...                                    ...             ...          ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD  202201036425.0    1482122-A
# 1074                 TP TEC HOLDING BERHAD  202401020280.0    1566129-V
# 1075                           TSIC BERHAD  202301036647.0    1530570-U
# 1076                  UCI RESOURCES BERHAD  202001015323.0    1371643-X
# 1077          UNI WALL APS HOLDINGS BERHAD  201801007506.0    1269520-X
#
#      company_type company_id
# 0         Company       5250
# 1         Company       5326
# 2         Company       7214
# 3         Company       7167
# 4         Company       7086
# ...           ...        ...
# 1073      Company      03058
# 1074      Company      03061
# 1075      Company      03062
# 1076      Company      03043
# 1077      Company      03017
#
# [1078 rows x 6 columns]

# %%
len(merge["company_id"].drop_duplicates())
# Out:
# 1078

# %%
merge_copy = merge.copy()

# %%
merge = merge.drop(columns="company_type")
merge = merge.rename(columns={
    "company_name": "company_name_bursa",
    "name_db": "company_name_api",
    "companyNo": "registration_number",
    "oldCompanyNo": "old_registration_number"
})
# merge.to_csv("bursa_company_registra.csv", index=False)

# %%
merge
# Out:
#                         company_name_bursa  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                           company_name_api registration_number  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD      201301028701.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2              A-RANK ASSOCIATES SDN. BHD.      199701029773.0
# 3             ABLE GLOBAL (MM2H) SDN. BHD.      199501013751.0
# 4                         ABLEGROUP BERHAD      200401015685.0
# ...                                    ...                 ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD      202201036425.0
# 1074                 TP TEC HOLDING BERHAD      202401020280.0
# 1075                           TSIC BERHAD      202301036647.0
# 1076                  UCI RESOURCES BERHAD      202001015323.0
# 1077          UNI WALL APS HOLDINGS BERHAD      201801007506.0
#
#      old_registration_number company_id
# 0                  1058531-W       5250
# 1                  1511706-T       5326
# 2                   445272-P       7214
# 3                   342952-P       7167
# 4                   654188-H       7086
# ...                      ...        ...
# 1073               1482122-A      03058
# 1074               1566129-V      03061
# 1075               1530570-U      03062
# 1076               1371643-X      03043
# 1077               1269520-X      03017
#
# [1078 rows x 5 columns]

# %%
merged
# Out:
#      company_id                                        company_url  \
# 0         03050  https://my.bursamalaysia.com/stock-details?sto...
# 1         03050  https://my.bursamalaysia.com/stock-details?sto...
# 2          5238  https://my.bursamalaysia.com/stock-details?sto...
# 3          5238  https://my.bursamalaysia.com/stock-details?sto...
# 4          5238  https://my.bursamalaysia.com/stock-details?sto...
# ...         ...                                                ...
# 3465       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3466       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3467       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3468       3905  https://my.bursamalaysia.com/stock-details?sto...
# 3469       3905  https://my.bursamalaysia.com/stock-details?sto...
#
#                          Name                             Designation  \
# 0                         NaN                                     NaN
# 1                         NaN                                     NaN
# 2     Mr. Benyamin Bin Ismail                 Chief Executive Officer
# 3           Ms. Lavinia Louis                 Chief Financial Officer
# 4         Capt. Suresh Bangah            Director - Flight Operations
# ...                       ...                                     ...
# 3465        Mr. Hoy Ping Chew  Non-Independent Non-Executive Director
# 3466                      NaN                                     NaN
# 3467                      NaN                                     NaN
# 3468                      NaN                                     NaN
# 3469                      NaN                                     NaN
#
#           Role   Since
# 0          NaN     NaN
# 1          NaN     NaN
# 2      Officer     NaN
# 3      Officer  2023.0
# 4      Officer  2013.0
# ...        ...     ...
# 3465  Director  2023.0
# 3466       NaN     NaN
# 3467       NaN     NaN
# 3468       NaN     NaN
# 3469       NaN     NaN
#
# [3470 rows x 6 columns]

# %%
merged["company_id"].nunique()
# Out:
# 172

# %%
merge["company_id"] = merge["company_id"].str.strip()
merged["company_id"] = merged["company_id"].str.strip()

# %%
merge["company_id"] = merge["company_id"].astype(str)
merged["company_id"] = merged["company_id"].astype(str)
final_merge = merge.merge(merged, on="company_id", how="inner")

# %%
final_merge['company_id'].nunique()
# Out:
# 172

# %%
merge
# Out:
#                         company_name_bursa  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                           company_name_api registration_number  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD      201301028701.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2              A-RANK ASSOCIATES SDN. BHD.      199701029773.0
# 3             ABLE GLOBAL (MM2H) SDN. BHD.      199501013751.0
# 4                         ABLEGROUP BERHAD      200401015685.0
# ...                                    ...                 ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD      202201036425.0
# 1074                 TP TEC HOLDING BERHAD      202401020280.0
# 1075                           TSIC BERHAD      202301036647.0
# 1076                  UCI RESOURCES BERHAD      202001015323.0
# 1077          UNI WALL APS HOLDINGS BERHAD      201801007506.0
#
#      old_registration_number company_id
# 0                  1058531-W       5250
# 1                  1511706-T       5326
# 2                   445272-P       7214
# 3                   342952-P       7167
# 4                   654188-H       7086
# ...                      ...        ...
# 1073               1482122-A      03058
# 1074               1566129-V      03061
# 1075               1530570-U      03062
# 1076               1371643-X      03043
# 1077               1269520-X      03017
#
# [1078 rows x 5 columns]

# %%
(final_merge.isnull().mean() * 100).sort_values(ascending=False).to_frame("missing_%").style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_aba5b_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_aba5b_row1_col0, #T_aba5b_row2_col0, #T_aba5b_row3_col0 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_aba5b_row4_col0, #T_aba5b_row5_col0, #T_aba5b_row6_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_aba5b_row7_col0, #T_aba5b_row8_col0, #T_aba5b_row9_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_aba5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aba5b_level0_col0" class="col_heading level0 col0" >missing_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aba5b_level0_row0" class="row_heading level0 row0" >Since</th>
#       <td id="T_aba5b_row0_col0" class="data row0 col0" >55.533141</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row1" class="row_heading level0 row1" >Name</th>
#       <td id="T_aba5b_row1_col0" class="data row1 col0" >45.504323</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row2" class="row_heading level0 row2" >Designation</th>
#       <td id="T_aba5b_row2_col0" class="data row2 col0" >45.504323</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row3" class="row_heading level0 row3" >Role</th>
#       <td id="T_aba5b_row3_col0" class="data row3 col0" >45.504323</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row4" class="row_heading level0 row4" >company_name_api</th>
#       <td id="T_aba5b_row4_col0" class="data row4 col0" >2.103746</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row5" class="row_heading level0 row5" >registration_number</th>
#       <td id="T_aba5b_row5_col0" class="data row5 col0" >2.103746</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row6" class="row_heading level0 row6" >old_registration_number</th>
#       <td id="T_aba5b_row6_col0" class="data row6 col0" >2.103746</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row7" class="row_heading level0 row7" >company_name_bursa</th>
#       <td id="T_aba5b_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row8" class="row_heading level0 row8" >company_id</th>
#       <td id="T_aba5b_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aba5b_level0_row9" class="row_heading level0 row9" >company_url</th>
#       <td id="T_aba5b_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df=final_merge

# %%
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 3465                  MCOM HOLDINGS BERHAD
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD
# 3467          SL INNOVATION CAPITAL BERHAD
# 3468                 SUNMOW HOLDING BERHAD
# 3469                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 3465                  MCOM HOLDINGS BERHAD      201701034106.0
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD      201901002105.0
# 3467          SL INNOVATION CAPITAL BERHAD      201101044035.0
# 3468                 SUNMOW HOLDING BERHAD      202001024626.0
# 3469                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 3465               1248277-X      03022
# 3466               1311431-K      03041
# 3467                972155-K      03008
# 3468               1380946-V      03050
# 3469               1380946-V      03050
#
#                                             company_url                  Name  \
# 0     https://my.bursamalaysia.com/stock-details?sto...     Mr. Thiam Wah Lee
# 1     https://my.bursamalaysia.com/stock-details?sto...      Ms. Yee Peng Ong
# 2     https://my.bursamalaysia.com/stock-details?sto...    Mr. Eng Kwang Yong
# 3     https://my.bursamalaysia.com/stock-details?sto...    Ms. Sau Chan Leong
# 4     https://my.bursamalaysia.com/stock-details?sto...  Mr. Yong Cherng Chia
# ...                                                 ...                   ...
# 3465  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3466  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3467  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3468  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3469  https://my.bursamalaysia.com/stock-details?sto...                   NaN
#
#                                       Designation     Role   Since
# 0     Chief Executive Officer, Executive Director     Both  2023.0
# 1                         Chief Financial Officer  Officer     NaN
# 2                         Chief Operating Officer  Officer     NaN
# 3                 Director - Business Development  Officer     NaN
# 4                            Director - Logistics  Officer     NaN
# ...                                           ...      ...     ...
# 3465                                          NaN      NaN     NaN
# 3466                                          NaN      NaN     NaN
# 3467                                          NaN      NaN     NaN
# 3468                                          NaN      NaN     NaN
# 3469                                          NaN      NaN     NaN
#
# [3470 rows x 10 columns]

# %%
# ── Your DataFrame ──
df = df.copy()
df.columns = df.columns.str.replace("-", " ").str.strip().str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 3465                  MCOM HOLDINGS BERHAD
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD
# 3467          SL INNOVATION CAPITAL BERHAD
# 3468                 SUNMOW HOLDING BERHAD
# 3469                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 3465                  MCOM HOLDINGS BERHAD      201701034106.0
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD      201901002105.0
# 3467          SL INNOVATION CAPITAL BERHAD      201101044035.0
# 3468                 SUNMOW HOLDING BERHAD      202001024626.0
# 3469                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 3465               1248277-X      03022
# 3466               1311431-K      03041
# 3467                972155-K      03008
# 3468               1380946-V      03050
# 3469               1380946-V      03050
#
#                                             company_url                  name  \
# 0     https://my.bursamalaysia.com/stock-details?sto...     Mr. Thiam Wah Lee
# 1     https://my.bursamalaysia.com/stock-details?sto...      Ms. Yee Peng Ong
# 2     https://my.bursamalaysia.com/stock-details?sto...    Mr. Eng Kwang Yong
# 3     https://my.bursamalaysia.com/stock-details?sto...    Ms. Sau Chan Leong
# 4     https://my.bursamalaysia.com/stock-details?sto...  Mr. Yong Cherng Chia
# ...                                                 ...                   ...
# 3465  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3466  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3467  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3468  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3469  https://my.bursamalaysia.com/stock-details?sto...                   NaN
#
#                                       designation     role   since
# 0     Chief Executive Officer, Executive Director     Both  2023.0
# 1                         Chief Financial Officer  Officer     NaN
# 2                         Chief Operating Officer  Officer     NaN
# 3                 Director - Business Development  Officer     NaN
# 4                            Director - Logistics  Officer     NaN
# ...                                           ...      ...     ...
# 3465                                          NaN      NaN     NaN
# 3466                                          NaN      NaN     NaN
# 3467                                          NaN      NaN     NaN
# 3468                                          NaN      NaN     NaN
# 3469                                          NaN      NaN     NaN
#
# [3470 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['company_name_bursa', 'company_name_api', 'registration_number',
#        'old_registration_number', 'company_id', 'company_url', 'name',
#        'designation', 'role', 'since'],
#       dtype='object')

# %%
import re
df.columns = (
    df.columns
    .str.replace("-", " ", regex=False)        # Replace hyphens with spaces
    .str.replace("/", " ", regex=False) 
    .str.strip()
    .str.lower()
    .str.replace(r"[^\w\s]", "", regex=True)   # Remove non-word characters like . , &
    .str.replace(r"\s+", "_", regex=True)      # Convert spaces to single underscore
    .str.replace(r"_+", "_", regex=True)       # Collapse multiple underscores to one
)

# %%
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 3465                  MCOM HOLDINGS BERHAD
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD
# 3467          SL INNOVATION CAPITAL BERHAD
# 3468                 SUNMOW HOLDING BERHAD
# 3469                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 3465                  MCOM HOLDINGS BERHAD      201701034106.0
# 3466     ONETECH SOLUTIONS HOLDINGS BERHAD      201901002105.0
# 3467          SL INNOVATION CAPITAL BERHAD      201101044035.0
# 3468                 SUNMOW HOLDING BERHAD      202001024626.0
# 3469                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 3465               1248277-X      03022
# 3466               1311431-K      03041
# 3467                972155-K      03008
# 3468               1380946-V      03050
# 3469               1380946-V      03050
#
#                                             company_url                  name  \
# 0     https://my.bursamalaysia.com/stock-details?sto...     Mr. Thiam Wah Lee
# 1     https://my.bursamalaysia.com/stock-details?sto...      Ms. Yee Peng Ong
# 2     https://my.bursamalaysia.com/stock-details?sto...    Mr. Eng Kwang Yong
# 3     https://my.bursamalaysia.com/stock-details?sto...    Ms. Sau Chan Leong
# 4     https://my.bursamalaysia.com/stock-details?sto...  Mr. Yong Cherng Chia
# ...                                                 ...                   ...
# 3465  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3466  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3467  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3468  https://my.bursamalaysia.com/stock-details?sto...                   NaN
# 3469  https://my.bursamalaysia.com/stock-details?sto...                   NaN
#
#                                       designation     role   since
# 0     Chief Executive Officer, Executive Director     Both  2023.0
# 1                         Chief Financial Officer  Officer     NaN
# 2                         Chief Operating Officer  Officer     NaN
# 3                 Director - Business Development  Officer     NaN
# 4                            Director - Logistics  Officer     NaN
# ...                                           ...      ...     ...
# 3465                                          NaN      NaN     NaN
# 3466                                          NaN      NaN     NaN
# 3467                                          NaN      NaN     NaN
# 3468                                          NaN      NaN     NaN
# 3469                                          NaN      NaN     NaN
#
# [3470 rows x 10 columns]

# %%
df.columns.tolist()
# Out:
# ['company_name_bursa',
#  'company_name_api',
#  'registration_number',
#  'old_registration_number',
#  'company_id',
#  'company_url',
#  'name',
#  'designation',
#  'role',
#  'since']

# %%
# Check for duplicate column names
duplicates = df.columns[df.columns.duplicated()]
print("Duplicate columns:", duplicates.tolist())
df = df.loc[:, ~df.columns.duplicated()]
# Out:
# Duplicate columns: []

# %%
# Get null ratios sorted
null_ratios = df.isnull().mean().sort_values(ascending=False)

# Convert to DataFrame with formatted percentage
summary_df = pd.DataFrame({
    "column": null_ratios.index,
    "null_ratio": (null_ratios * 100).map("{:.2f}%".format)
})

# Save to CSV
# summary_df.to_csv("/insider_null_ratio_summary.csv", index=False)
summary_df.head()
# Out:
#                             column null_ratio
# since                        since     55.53%
# name                          name     45.50%
# designation            designation     45.50%
# role                          role     45.50%
# company_name_api  company_name_api      2.10%

# %%
len(df["registration_number"].drop_duplicates())
# Out:
# 170

# %%
df = df.dropna(subset=["registration_number"])

# %%
df['registration_number'].nunique()
# Out:
# 169

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# ── Load environment variables ──
load_dotenv()

# ── Read DB credentials ──
user = os.getenv("PG_USER")
password = os.getenv("PG_PASSWORD")
host = os.getenv("PG_HOST")
port = os.getenv("PG_PORT")
database = os.getenv("PG_DATABASE")

# ── Create connection string ──
connection_url = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_url)

# ── Your DataFrame ──
df = df.copy()

# ── Push to DB ──
df.to_sql("public_complete_directors_executives", engine, schema="public", index=False, if_exists="replace")

print("✅ Uploaded to 'public_complete_directors_executives' with normalized column names.")
# Out:
# ✅ Uploaded to 'public_complete_directors_executives' with normalized column names.
