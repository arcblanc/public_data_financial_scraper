# %%
import pandas as pd

# %%
csv = pd.read_csv("../complete_cash_flow_statements.csv",keep_default_na=True,na_values=["None", "none", "NaN", "-"],low_memory=False,dtype={"company_id": str})
csv["company_id"] = csv["company_id"].astype(str)

# %%
df = csv
bad_ids = df[~df["company_id"].str.fullmatch(r"\d{4}")]
print("Bad company_ids:")
print(bad_ids['company_id'])
# Out:
# Bad company_ids:
# 64      03008
# 65      03008
# 66      03008
# 67      03008
# 68      03008
#         ...
# 9657    03039
# 9658    03039
# 9659    03039
# 9660    03039
# 9661    03039
# Name: company_id, Length: 378, dtype: object

# %%
# Ensure company_id is string
csv["company_id"] = csv["company_id"].astype(str)

# Detect bad IDs (not exactly 4 digits)
bad_mask = ~csv["company_id"].str.fullmatch(r"\d{4}")

# Print them
print("Bad company_ids:")
print(csv.loc[bad_mask, "company_id"])

# Fix only the bad ones
csv.loc[bad_mask, "company_id"] = csv.loc[bad_mask, "company_id"].str.zfill(4)
# Out:
# Bad company_ids:
# 64      03008
# 65      03008
# 66      03008
# 67      03008
# 68      03008
#         ...
# 9657    03039
# 9658    03039
# 9659    03039
# 9660    03039
# 9661    03039
# Name: company_id, Length: 378, dtype: object

# %%
# Ensure company_id is string type
csv["company_id"] = csv["company_id"].astype(str)

# Find malformed IDs that are not 4-digit strings
bad_ids = csv[~csv["company_id"].str.fullmatch(r"\d{4}")]

# Report bad IDs
print("Bad company_ids:")
print(bad_ids["company_id"])
# Out:
# Bad company_ids:
# 64      03008
# 65      03008
# 66      03008
# 67      03008
# 68      03008
#         ...
# 9657    03039
# 9658    03039
# 9659    03039
# 9660    03039
# 9661    03039
# Name: company_id, Length: 378, dtype: object

# %%
df = csv

# %%
import pandas as pd

# Step 1: Separate Value and YoY rows
df_value = df[df["Year/Type"].str.contains("Value", na=False)].copy()
df_yoy = df[df["Year/Type"].str.contains("YoY %", na=False)].copy()

# Step 2: Extract full date from "Year/Type" (e.g., '31 Mar 2024')
df_value["Fiscal Date"] = df_value["Year/Type"].str.extract(r"(\d{1,2} \w{3} \d{4})")
df_yoy["Fiscal Date"] = df_yoy["Year/Type"].str.extract(r"(\d{1,2} \w{3} \d{4})")

# Step 3: Merge on 'company_id' and 'Fiscal Date'
merged = pd.merge(
    df_value,
    df_yoy,
    on=["company_id", "Fiscal Date"],
    suffixes=("", "_yoy"),
    how="left"
)

# Drop helper columns
merged = merged.drop(columns=["Year/Type", "Year/Type_yoy"])
merged = merged.rename(columns={"Fiscal Date": "Fiscal Date"})

merged.head()
# Out:
#   company_id Cash Receipts Cash Payments Net Income/Starting Line  \
# 0       5274           NaN           NaN                   121.86
# 1       5274           NaN           NaN                    61.43
# 2       5274           NaN           NaN                    97.17
# 3       5274           NaN           NaN                   177.35
# 4       5274           NaN           NaN                    95.75
#
#   Depreciation/Depletion Depreciation Amortization  \
# 0                   7.30         7.30         2.44
# 1                   8.53         8.53         2.31
# 2                   8.02         8.02         1.88
# 3                   7.63         7.63         1.53
# 4                   7.39         7.39         1.70
#
#    Amortization of Acquisition Costs Amortization of Intangibles  \
# 0                                NaN                        2.44
# 1                                NaN                        2.31
# 2                                NaN                        1.88
# 3                                NaN                        1.53
# 4                                NaN                        1.70
#
#   Deferred Taxes  ... Unearned Premiums_yoy Insurance Reserves_yoy  \
# 0            NaN  ...                   NaN                    NaN
# 1            NaN  ...                   NaN                    NaN
# 2            NaN  ...                   NaN                    NaN
# 3            NaN  ...                   NaN                    NaN
# 4            NaN  ...                   NaN                    NaN
#
#   Investment Securities, Gains/Losses_yoy  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Sale/Issuance of Common/Preferred_yoy Loans Origination - Operating_yoy  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#   Loan Loss Provision_yoy Loans, Gains/Losses_yoy Foreclosed Real Estate_yoy  \
# 0                     NaN                     NaN                        NaN
# 1                     NaN                     NaN                        NaN
# 2                     NaN                     NaN                        NaN
# 3                     NaN                     NaN                        NaN
# 4                     NaN                     NaN                        NaN
#
#   Deposits_yoy Repurchase/Retirement of Preferred_yoy
# 0          NaN                                    NaN
# 1          NaN                                    NaN
# 2          NaN                                    NaN
# 3          NaN                                    NaN
# 4          NaN                                    NaN
#
# [5 rows x 168 columns]

# %%
# Find all _yoy columns
yoy_cols = [col for col in merged.columns if col.endswith('_yoy')]

# Identify _yoy columns that do NOT contain any '%' values
cols_to_drop = [
    col for col in yoy_cols
    if not merged[col].astype(str).str.contains('%', na=False).any()
]

# Drop them
merged = merged.drop(columns=cols_to_drop)

print(f"✅ Dropped {len(cols_to_drop)} _yoy columns without '%' signs.")
# Out:
# ✅ Dropped 13 _yoy columns without '%' signs.

# %%
len(merged.columns)
# Out:
# 155

# %%
merged
# Out:
#      company_id Cash Receipts Cash Payments Net Income/Starting Line  \
# 0          5274           NaN           NaN                   121.86
# 1          5274           NaN           NaN                    61.43
# 2          5274           NaN           NaN                    97.17
# 3          5274           NaN           NaN                   177.35
# 4          5274           NaN           NaN                    95.75
# ...         ...           ...           ...                      ...
# 4838       5292           NaN           NaN                    18.78
# 4839       5292           NaN           NaN                    67.88
# 4840       5292           NaN           NaN                   139.74
# 4841       5292           NaN           NaN                   114.79
# 4842       5292           NaN           NaN                    72.63
#
#      Depreciation/Depletion Depreciation Amortization  \
# 0                      7.30         7.30         2.44
# 1                      8.53         8.53         2.31
# 2                      8.02         8.02         1.88
# 3                      7.63         7.63         1.53
# 4                      7.39         7.39         1.70
# ...                     ...          ...          ...
# 4838                  21.27        21.27          NaN
# 4839                  18.29        18.29          NaN
# 4840                  15.58        15.58          NaN
# 4841                  12.71        12.71          NaN
# 4842                  10.47        10.47          NaN
#
#       Amortization of Acquisition Costs Amortization of Intangibles  \
# 0                                   NaN                        2.44
# 1                                   NaN                        2.31
# 2                                   NaN                        1.88
# 3                                   NaN                        1.53
# 4                                   NaN                        1.70
# ...                                 ...                         ...
# 4838                                NaN                         NaN
# 4839                                NaN                         NaN
# 4840                                NaN                         NaN
# 4841                                NaN                         NaN
# 4842                                NaN                         NaN
#
#      Deferred Taxes  ... Cash Interest Paid_yoy Cash Taxes Paid_yoy  \
# 0               NaN  ...                -24.26%              10.38%
# 1               NaN  ...                -59.45%             -26.52%
# 2               NaN  ...                -23.04%             -13.62%
# 3               NaN  ...                103.61%             -14.58%
# 4               NaN  ...                116.07%              67.81%
# ...             ...  ...                    ...                 ...
# 4838            NaN  ...                -60.00%             -35.45%
# 4839            NaN  ...                -16.67%               0.99%
# 4840            NaN  ...                -45.45%              70.85%
# 4841            NaN  ...                -63.33%              48.93%
# 4842            NaN  ...                -87.18%              80.61%
#
#      Foreign Exchange Effects_yoy Deferred Policy Acquisition Costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                     -252.11%                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                          NaN                                   NaN
# 4842                          NaN                                   NaN
#
#      Reinsurance Receivable_yoy Reinsurance Payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      Investment Securities, Gains/Losses_yoy Loan Loss Provision_yoy  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                                        NaN                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 4838                                     NaN                     NaN
# 4839                                     NaN                     NaN
# 4840                                     NaN                     NaN
# 4841                                     NaN                     NaN
# 4842                                     NaN                     NaN
#
#      Loans, Gains/Losses_yoy Foreclosed Real Estate_yoy
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 4838                     NaN                        NaN
# 4839                     NaN                        NaN
# 4840                     NaN                        NaN
# 4841                     NaN                        NaN
# 4842                     NaN                        NaN
#
# [4843 rows x 155 columns]

# %%
bursa_registration = pd.read_csv("../matched_companies_from_ssm.csv",dtype={"company_id": str,"companyNo": str})
bursa_registration["companyNo"] = (
    bursa_registration["companyNo"]
    .astype(str)
    .str.replace(r"\.0$", "", regex=True)
    .str.strip()
)
bursa_registration.head()
# Out:
#                            company_name                               name_db  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD     7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1  99 SPEED MART RETAIL HOLDINGS BERHAD  99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                         A-RANK BERHAD           A-RANK ASSOCIATES SDN. BHD.
# 3                    ABLE GLOBAL BERHAD          ABLE GLOBAL (MM2H) SDN. BHD.
# 4                      ABLEGROUP BERHAD                      ABLEGROUP BERHAD
#
#         companyNo oldCompanyNo company_type
# 0  201301028701.0    1058531-W      Company
# 1  202301017784.0    1511706-T      Company
# 2  199701029773.0     445272-P      Company
# 3  199501013751.0     342952-P      Company
# 4  200401015685.0     654188-H      Company

# %%
company_id = pd.read_csv("../../../list_bursa_ids/bursa_company_list.csv", dtype={"company_id": str})
company_id["company_id"] = company_id["company_id"].str.strip().str.zfill(4)

# %%
merge = pd.merge(bursa_registration,company_id,on="company_name",how="inner")
merge
# Out:
#                               company_name  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                                    name_db       companyNo oldCompanyNo  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD  201301028701.0    1058531-W
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD  202301017784.0    1511706-T
# 2              A-RANK ASSOCIATES SDN. BHD.  199701029773.0     445272-P
# 3             ABLE GLOBAL (MM2H) SDN. BHD.  199501013751.0     342952-P
# 4                         ABLEGROUP BERHAD  200401015685.0     654188-H
# ...                                    ...             ...          ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD  202201036425.0    1482122-A
# 1074                 TP TEC HOLDING BERHAD  202401020280.0    1566129-V
# 1075                           TSIC BERHAD  202301036647.0    1530570-U
# 1076                  UCI RESOURCES BERHAD  202001015323.0    1371643-X
# 1077          UNI WALL APS HOLDINGS BERHAD  201801007506.0    1269520-X
#
#      company_type company_id
# 0         Company       5250
# 1         Company       5326
# 2         Company       7214
# 3         Company       7167
# 4         Company       7086
# ...           ...        ...
# 1073      Company      03058
# 1074      Company      03061
# 1075      Company      03062
# 1076      Company      03043
# 1077      Company      03017
#
# [1078 rows x 6 columns]

# %%
len(merge["company_id"].drop_duplicates())
# Out:
# 1078

# %%
merge_copy = merge.copy()

# %%
merge = merge.drop(columns="company_type")
merge = merge.rename(columns={
    "company_name": "company_name_bursa",
    "name_db": "company_name_api",
    "companyNo": "registration_number",
    "oldCompanyNo": "old_registration_number"
})
# merge.to_csv("bursa_company_registra.csv", index=False)

# %%
merge
# Out:
#                         company_name_bursa  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                           company_name_api registration_number  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD      201301028701.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2              A-RANK ASSOCIATES SDN. BHD.      199701029773.0
# 3             ABLE GLOBAL (MM2H) SDN. BHD.      199501013751.0
# 4                         ABLEGROUP BERHAD      200401015685.0
# ...                                    ...                 ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD      202201036425.0
# 1074                 TP TEC HOLDING BERHAD      202401020280.0
# 1075                           TSIC BERHAD      202301036647.0
# 1076                  UCI RESOURCES BERHAD      202001015323.0
# 1077          UNI WALL APS HOLDINGS BERHAD      201801007506.0
#
#      old_registration_number company_id
# 0                  1058531-W       5250
# 1                  1511706-T       5326
# 2                   445272-P       7214
# 3                   342952-P       7167
# 4                   654188-H       7086
# ...                      ...        ...
# 1073               1482122-A      03058
# 1074               1566129-V      03061
# 1075               1530570-U      03062
# 1076               1371643-X      03043
# 1077               1269520-X      03017
#
# [1078 rows x 5 columns]

# %%
merged
# Out:
#      company_id Cash Receipts Cash Payments Net Income/Starting Line  \
# 0          5274           NaN           NaN                   121.86
# 1          5274           NaN           NaN                    61.43
# 2          5274           NaN           NaN                    97.17
# 3          5274           NaN           NaN                   177.35
# 4          5274           NaN           NaN                    95.75
# ...         ...           ...           ...                      ...
# 4838       5292           NaN           NaN                    18.78
# 4839       5292           NaN           NaN                    67.88
# 4840       5292           NaN           NaN                   139.74
# 4841       5292           NaN           NaN                   114.79
# 4842       5292           NaN           NaN                    72.63
#
#      Depreciation/Depletion Depreciation Amortization  \
# 0                      7.30         7.30         2.44
# 1                      8.53         8.53         2.31
# 2                      8.02         8.02         1.88
# 3                      7.63         7.63         1.53
# 4                      7.39         7.39         1.70
# ...                     ...          ...          ...
# 4838                  21.27        21.27          NaN
# 4839                  18.29        18.29          NaN
# 4840                  15.58        15.58          NaN
# 4841                  12.71        12.71          NaN
# 4842                  10.47        10.47          NaN
#
#       Amortization of Acquisition Costs Amortization of Intangibles  \
# 0                                   NaN                        2.44
# 1                                   NaN                        2.31
# 2                                   NaN                        1.88
# 3                                   NaN                        1.53
# 4                                   NaN                        1.70
# ...                                 ...                         ...
# 4838                                NaN                         NaN
# 4839                                NaN                         NaN
# 4840                                NaN                         NaN
# 4841                                NaN                         NaN
# 4842                                NaN                         NaN
#
#      Deferred Taxes  ... Cash Interest Paid_yoy Cash Taxes Paid_yoy  \
# 0               NaN  ...                -24.26%              10.38%
# 1               NaN  ...                -59.45%             -26.52%
# 2               NaN  ...                -23.04%             -13.62%
# 3               NaN  ...                103.61%             -14.58%
# 4               NaN  ...                116.07%              67.81%
# ...             ...  ...                    ...                 ...
# 4838            NaN  ...                -60.00%             -35.45%
# 4839            NaN  ...                -16.67%               0.99%
# 4840            NaN  ...                -45.45%              70.85%
# 4841            NaN  ...                -63.33%              48.93%
# 4842            NaN  ...                -87.18%              80.61%
#
#      Foreign Exchange Effects_yoy Deferred Policy Acquisition Costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                     -252.11%                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                          NaN                                   NaN
# 4842                          NaN                                   NaN
#
#      Reinsurance Receivable_yoy Reinsurance Payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      Investment Securities, Gains/Losses_yoy Loan Loss Provision_yoy  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                                        NaN                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 4838                                     NaN                     NaN
# 4839                                     NaN                     NaN
# 4840                                     NaN                     NaN
# 4841                                     NaN                     NaN
# 4842                                     NaN                     NaN
#
#      Loans, Gains/Losses_yoy Foreclosed Real Estate_yoy
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 4838                     NaN                        NaN
# 4839                     NaN                        NaN
# 4840                     NaN                        NaN
# 4841                     NaN                        NaN
# 4842                     NaN                        NaN
#
# [4843 rows x 155 columns]

# %%
merged["company_id"].nunique()
# Out:
# 1033

# %%
merge["company_id"] = merge["company_id"].str.strip()
merged["company_id"] = merged["company_id"].str.strip()

# %%
merge["company_id"] = merge["company_id"].astype(str)
merged["company_id"] = merged["company_id"].astype(str)
final_merge = merge.merge(merged, on="company_id", how="inner")

# %%
final_merge['company_id'].nunique()
# Out:
# 1033

# %%
(final_merge.isnull().mean() * 100).sort_values(ascending=False).to_frame("missing_%").style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_292b6_row0_col0, #T_292b6_row1_col0, #T_292b6_row2_col0, #T_292b6_row3_col0, #T_292b6_row4_col0, #T_292b6_row5_col0, #T_292b6_row6_col0, #T_292b6_row7_col0, #T_292b6_row8_col0, #T_292b6_row9_col0, #T_292b6_row10_col0, #T_292b6_row11_col0, #T_292b6_row12_col0, #T_292b6_row13_col0, #T_292b6_row14_col0, #T_292b6_row15_col0, #T_292b6_row16_col0, #T_292b6_row17_col0, #T_292b6_row18_col0, #T_292b6_row19_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_292b6_row20_col0, #T_292b6_row21_col0 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_292b6_row22_col0, #T_292b6_row23_col0, #T_292b6_row24_col0, #T_292b6_row25_col0, #T_292b6_row26_col0, #T_292b6_row27_col0 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_292b6_row28_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_292b6_row29_col0, #T_292b6_row30_col0 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_292b6_row31_col0, #T_292b6_row32_col0 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_292b6_row33_col0, #T_292b6_row34_col0, #T_292b6_row35_col0, #T_292b6_row36_col0, #T_292b6_row37_col0 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_292b6_row38_col0 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_292b6_row39_col0 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_292b6_row40_col0, #T_292b6_row41_col0 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_292b6_row42_col0, #T_292b6_row43_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_292b6_row44_col0, #T_292b6_row45_col0 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_292b6_row46_col0, #T_292b6_row47_col0 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_292b6_row48_col0 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_292b6_row49_col0, #T_292b6_row50_col0, #T_292b6_row51_col0 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_292b6_row52_col0 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_292b6_row53_col0 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_292b6_row54_col0 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_292b6_row55_col0 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_292b6_row56_col0 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_292b6_row57_col0 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_292b6_row58_col0 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_292b6_row59_col0, #T_292b6_row60_col0 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_292b6_row61_col0 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_292b6_row62_col0 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_292b6_row63_col0 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_292b6_row64_col0 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_292b6_row65_col0 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_292b6_row66_col0 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_292b6_row67_col0 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_292b6_row68_col0 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_292b6_row69_col0, #T_292b6_row70_col0 {
#   background-color: #e02c26;
#   color: #f1f1f1;
# }
# #T_292b6_row71_col0 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_292b6_row72_col0 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_292b6_row73_col0, #T_292b6_row74_col0, #T_292b6_row75_col0 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_292b6_row76_col0 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_292b6_row77_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_292b6_row78_col0 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_292b6_row79_col0 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_292b6_row80_col0 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_292b6_row81_col0 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_292b6_row82_col0 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_292b6_row83_col0 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_292b6_row84_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_292b6_row85_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_292b6_row86_col0 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_292b6_row87_col0 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_292b6_row88_col0 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_292b6_row89_col0 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_292b6_row90_col0 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_292b6_row91_col0 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_292b6_row92_col0 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_292b6_row93_col0 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_292b6_row94_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_292b6_row95_col0 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_292b6_row96_col0, #T_292b6_row97_col0 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_292b6_row98_col0, #T_292b6_row99_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_292b6_row100_col0 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_292b6_row101_col0, #T_292b6_row102_col0, #T_292b6_row103_col0 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_292b6_row104_col0 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_292b6_row105_col0 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_292b6_row106_col0, #T_292b6_row107_col0 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_292b6_row108_col0 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_292b6_row109_col0, #T_292b6_row110_col0 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_292b6_row111_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_292b6_row112_col0, #T_292b6_row113_col0, #T_292b6_row114_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_292b6_row115_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_292b6_row116_col0, #T_292b6_row117_col0 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_292b6_row118_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_292b6_row119_col0, #T_292b6_row120_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_292b6_row121_col0, #T_292b6_row122_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_292b6_row123_col0, #T_292b6_row124_col0, #T_292b6_row125_col0, #T_292b6_row126_col0, #T_292b6_row127_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_292b6_row128_col0, #T_292b6_row129_col0, #T_292b6_row130_col0, #T_292b6_row131_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_292b6_row132_col0 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_292b6_row133_col0, #T_292b6_row134_col0, #T_292b6_row135_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_292b6_row136_col0, #T_292b6_row137_col0, #T_292b6_row138_col0, #T_292b6_row139_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_292b6_row140_col0, #T_292b6_row141_col0, #T_292b6_row142_col0, #T_292b6_row143_col0, #T_292b6_row144_col0, #T_292b6_row145_col0, #T_292b6_row146_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_292b6_row147_col0, #T_292b6_row148_col0, #T_292b6_row149_col0, #T_292b6_row150_col0, #T_292b6_row151_col0, #T_292b6_row152_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_292b6_row153_col0, #T_292b6_row154_col0, #T_292b6_row155_col0, #T_292b6_row156_col0, #T_292b6_row157_col0, #T_292b6_row158_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_292b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_292b6_level0_col0" class="col_heading level0 col0" >missing_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_292b6_level0_row0" class="row_heading level0 row0" >Insurance Reserves</th>
#       <td id="T_292b6_row0_col0" class="data row0 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_292b6_level0_row1" class="row_heading level0 row1" >Reported Cash from Operating Activities</th>
#       <td id="T_292b6_row1_col0" class="data row1 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_292b6_level0_row2

# %%
df=final_merge

# %%
df
# Out:
#                      company_name_bursa                   company_name_api  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 3     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 4     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# ...                                 ...                                ...
# 4838               UCI RESOURCES BERHAD               UCI RESOURCES BERHAD
# 4839       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4840       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4841       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4842       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
#
#      registration_number old_registration_number company_id Cash Receipts  \
# 0         201301028701.0               1058531-W       5250      3,058.75
# 1         201301028701.0               1058531-W       5250      4,358.27
# 2         201301028701.0               1058531-W       5250      4,010.94
# 3         201301028701.0               1058531-W       5250      3,041.35
# 4         201301028701.0               1058531-W       5250      2,732.29
# ...                  ...                     ...        ...           ...
# 4838      202001015323.0               1371643-X      03043           NaN
# 4839      201801007506.0               1269520-X      03017           NaN
# 4840      201801007506.0               1269520-X      03017           NaN
# 4841      201801007506.0               1269520-X      03017           NaN
# 4842      201801007506.0               1269520-X      03017           NaN
#
#      Cash Payments Net Income/Starting Line Depreciation/Depletion  \
# 0        -2,881.78                      NaN                    NaN
# 1        -3,984.39                      NaN                    NaN
# 2        -3,459.32                      NaN                    NaN
# 3        -2,705.03                      NaN                    NaN
# 4        -2,454.78                      NaN                    NaN
# ...            ...                      ...                    ...
# 4838           NaN                     2.26                   1.22
# 4839           NaN                     4.55                   0.99
# 4840           NaN                   -12.35                   1.42
# 4841           NaN                     5.59                   0.89
# 4842           NaN                     9.67                   0.73
#
#      Depreciation  ... Cash Interest Paid_yoy  Cash Taxes Paid_yoy  \
# 0             NaN  ...                 16.71%               55.88%
# 1             NaN  ...                -18.73%              -45.51%
# 2             NaN  ...                -14.89%              -19.42%
# 3             NaN  ...                -28.92%              -43.84%
# 4             NaN  ...               -157.40%              -33.04%
# ...           ...  ...                    ...                  ...
# 4838         1.22  ...                -15.00%              -68.94%
# 4839         0.99  ...                -44.66%              -81.67%
# 4840         1.42  ...                128.89%              -72.48%
# 4841         0.89  ...                 57.89%              938.10%
# 4842         0.73  ...                 29.55%              -94.41%
#
#      Foreign Exchange Effects_yoy Deferred Policy Acquisition Costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                          NaN                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                        0.00%                                   NaN
# 4842                          NaN                                   NaN
#
#      Reinsurance Receivable_yoy Reinsurance Payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      Investment Securities, Gains/Losses_yoy Loan Loss Provision_yoy  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                                        NaN                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 4838                                     NaN                     NaN
# 4839                                     NaN                     NaN
# 4840                                     NaN                     NaN
# 4841                                     NaN                     NaN
# 4842                                     NaN                     NaN
#
#      Loans, Gains/Losses_yoy Foreclosed Real Estate_yoy
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 4838                     NaN                        NaN
# 4839                     NaN                        NaN
# 4840                     NaN                        NaN
# 4841                     NaN                        NaN
# 4842                     NaN                        NaN
#
# [4843 rows x 159 columns]

# %%
df["Fiscal Date"]
# Out:
# 0       31 Dec 2024
# 1       31 Dec 2023
# 2       31 Dec 2022
# 3       31 Dec 2021
# 4       31 Dec 2020
#            ...
# 4838    31 Dec 2020
# 4839    30 Jun 2024
# 4840    30 Jun 2023
# 4841    31 Dec 2021
# 4842    31 Dec 2020
# Name: Fiscal Date, Length: 4843, dtype: object

# %%
# ── Your DataFrame ──
df = df.copy()
df.columns = df.columns.str.replace("-", " ").str.strip().str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
df
# Out:
#                      company_name_bursa                   company_name_api  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 3     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 4     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# ...                                 ...                                ...
# 4838               UCI RESOURCES BERHAD               UCI RESOURCES BERHAD
# 4839       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4840       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4841       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4842       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
#
#      registration_number old_registration_number company_id cash_receipts  \
# 0         201301028701.0               1058531-W       5250      3,058.75
# 1         201301028701.0               1058531-W       5250      4,358.27
# 2         201301028701.0               1058531-W       5250      4,010.94
# 3         201301028701.0               1058531-W       5250      3,041.35
# 4         201301028701.0               1058531-W       5250      2,732.29
# ...                  ...                     ...        ...           ...
# 4838      202001015323.0               1371643-X      03043           NaN
# 4839      201801007506.0               1269520-X      03017           NaN
# 4840      201801007506.0               1269520-X      03017           NaN
# 4841      201801007506.0               1269520-X      03017           NaN
# 4842      201801007506.0               1269520-X      03017           NaN
#
#      cash_payments net_income/starting_line depreciation/depletion  \
# 0        -2,881.78                      NaN                    NaN
# 1        -3,984.39                      NaN                    NaN
# 2        -3,459.32                      NaN                    NaN
# 3        -2,705.03                      NaN                    NaN
# 4        -2,454.78                      NaN                    NaN
# ...            ...                      ...                    ...
# 4838           NaN                     2.26                   1.22
# 4839           NaN                     4.55                   0.99
# 4840           NaN                   -12.35                   1.42
# 4841           NaN                     5.59                   0.89
# 4842           NaN                     9.67                   0.73
#
#      depreciation  ... cash_interest_paid_yoy  cash_taxes_paid_yoy  \
# 0             NaN  ...                 16.71%               55.88%
# 1             NaN  ...                -18.73%              -45.51%
# 2             NaN  ...                -14.89%              -19.42%
# 3             NaN  ...                -28.92%              -43.84%
# 4             NaN  ...               -157.40%              -33.04%
# ...           ...  ...                    ...                  ...
# 4838         1.22  ...                -15.00%              -68.94%
# 4839         0.99  ...                -44.66%              -81.67%
# 4840         1.42  ...                128.89%              -72.48%
# 4841         0.89  ...                 57.89%              938.10%
# 4842         0.73  ...                 29.55%              -94.41%
#
#      foreign_exchange_effects_yoy deferred_policy_acquisition_costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                          NaN                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                        0.00%                                   NaN
# 4842                          NaN                                   NaN
#
#      reinsurance_receivable_yoy reinsurance_payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      investment_securities,_gains/losses_yoy loan_loss_provision_yoy  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                                        NaN                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 4838                                     NaN                     NaN
# 4839                                     NaN                     NaN
# 4840                                     NaN                     NaN
# 4841                                     NaN                     NaN
# 4842                                     NaN                     NaN
#
#      loans,_gains/losses_yoy foreclosed_real_estate_yoy
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 4838                     NaN                        NaN
# 4839                     NaN                        NaN
# 4840                     NaN                        NaN
# 4841                     NaN                        NaN
# 4842                     NaN                        NaN
#
# [4843 rows x 159 columns]

# %%
df.columns
# Out:
# Index(['company_name_bursa', 'company_name_api', 'registration_number',
#        'old_registration_number', 'company_id', 'cash_receipts',
#        'cash_payments', 'net_income/starting_line', 'depreciation/depletion',
#        'depreciation',
#        ...
#        'cash_interest_paid_yoy', 'cash_taxes_paid_yoy',
#        'foreign_exchange_effects_yoy', 'deferred_policy_acquisition_costs_yoy',
#        'reinsurance_receivable_yoy', 'reinsurance_payable_yoy',
#        'investment_securities,_gains/losses_yoy', 'loan_loss_provision_yoy',
#        'loans,_gains/losses_yoy', 'foreclosed_real_estate_yoy'],
#       dtype='object', length=159)

# %%
import re
df.columns = (
    df.columns
    .str.replace("-", " ", regex=False)        # Replace hyphens with spaces
    .str.replace("/", " ", regex=False) 
    .str.strip()
    .str.lower()
    .str.replace(r"[^\w\s]", "", regex=True)   # Remove non-word characters like . , &
    .str.replace(r"\s+", "_", regex=True)      # Convert spaces to single underscore
    .str.replace(r"_+", "_", regex=True)       # Collapse multiple underscores to one
)

# %%
df
# Out:
#                      company_name_bursa                   company_name_api  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 3     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 4     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# ...                                 ...                                ...
# 4838               UCI RESOURCES BERHAD               UCI RESOURCES BERHAD
# 4839       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4840       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4841       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4842       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
#
#      registration_number old_registration_number company_id cash_receipts  \
# 0         201301028701.0               1058531-W       5250      3,058.75
# 1         201301028701.0               1058531-W       5250      4,358.27
# 2         201301028701.0               1058531-W       5250      4,010.94
# 3         201301028701.0               1058531-W       5250      3,041.35
# 4         201301028701.0               1058531-W       5250      2,732.29
# ...                  ...                     ...        ...           ...
# 4838      202001015323.0               1371643-X      03043           NaN
# 4839      201801007506.0               1269520-X      03017           NaN
# 4840      201801007506.0               1269520-X      03017           NaN
# 4841      201801007506.0               1269520-X      03017           NaN
# 4842      201801007506.0               1269520-X      03017           NaN
#
#      cash_payments net_income_starting_line depreciation_depletion  \
# 0        -2,881.78                      NaN                    NaN
# 1        -3,984.39                      NaN                    NaN
# 2        -3,459.32                      NaN                    NaN
# 3        -2,705.03                      NaN                    NaN
# 4        -2,454.78                      NaN                    NaN
# ...            ...                      ...                    ...
# 4838           NaN                     2.26                   1.22
# 4839           NaN                     4.55                   0.99
# 4840           NaN                   -12.35                   1.42
# 4841           NaN                     5.59                   0.89
# 4842           NaN                     9.67                   0.73
#
#      depreciation  ... cash_interest_paid_yoy  cash_taxes_paid_yoy  \
# 0             NaN  ...                 16.71%               55.88%
# 1             NaN  ...                -18.73%              -45.51%
# 2             NaN  ...                -14.89%              -19.42%
# 3             NaN  ...                -28.92%              -43.84%
# 4             NaN  ...               -157.40%              -33.04%
# ...           ...  ...                    ...                  ...
# 4838         1.22  ...                -15.00%              -68.94%
# 4839         0.99  ...                -44.66%              -81.67%
# 4840         1.42  ...                128.89%              -72.48%
# 4841         0.89  ...                 57.89%              938.10%
# 4842         0.73  ...                 29.55%              -94.41%
#
#      foreign_exchange_effects_yoy deferred_policy_acquisition_costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                          NaN                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                        0.00%                                   NaN
# 4842                          NaN                                   NaN
#
#      reinsurance_receivable_yoy reinsurance_payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      investment_securities_gains_losses_yoy loan_loss_provision_yoy  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 4838                                    NaN                     NaN
# 4839                                    NaN                     NaN
# 4840                                    NaN                     NaN
# 4841                                    NaN                     NaN
# 4842                                    NaN                     NaN
#
#      loans_gains_losses_yoy foreclosed_real_estate_yoy
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 4838                    NaN                        NaN
# 4839                    NaN                        NaN
# 4840                    NaN                        NaN
# 4841                    NaN                        NaN
# 4842                    NaN                        NaN
#
# [4843 rows x 159 columns]

# %%
# Check for duplicate column names
duplicates = df.columns[df.columns.duplicated()]
print("Duplicate columns:", duplicates.tolist())
df = df.loc[:, ~df.columns.duplicated()]
# Out:
# Duplicate columns: []

# %%
df.columns.tolist()
# Out:
# ['company_name_bursa',
#  'company_name_api',
#  'registration_number',
#  'old_registration_number',
#  'company_id',
#  'cash_receipts',
#  'cash_payments',
#  'net_income_starting_line',
#  'depreciation_depletion',
#  'depreciation',
#  'amortization',
#  'amortization_of_acquisition_costs',
#  'amortization_of_intangibles',
#  'deferred_taxes',
#  'non_cash_items',
#  'discontinued_operations',
#  'equity_in_net_earnings_loss',
#  'unusual_items',
#  'other_non_cash_items',
#  'changes_in_working_capital',
#  'other_assets_liabilities_net',
#  'other_assets',
#  'other_liabilities',
#  'accounts_receivable',
#  'inventories',
#  'accounts_payable',
#  'payable_accrued',
#  'other_operating_cash_flow',
#  'cash_from_operating_activities',
#  'capital_expenditures',
#  'purchase_acquisition_of_intangibles',
#  'purchase_of_fixed_assets',
#  'other_investing_cash_flow_items_total',
#  'sale_maturity_of_investment',
#  'purchase_of_investments',
#  'sale_of_intangible_assets',
#  'sale_of_business',
#  'investment_net',
#  'acquisition_of_business',
#  'sale_of_fixed_assets',
#  'intangible_net',
#  'other_investing_cash_flow',
#  'cash_from_investing_activities',
#  'financing_cash_flow_items',
#  'other_financing_cash_flow',
#  'total_cash_dividends_paid',
#  'cash_dividends_paid_common',
#  'issuance_retirement_of_stock_net',
#  'sale_issuance_of_common',
#  'repurchase_retirement_of_common',
#  'common_stock_net',
#  'warrants_converted',
#  'issuance_retirement_of_debt_net',
#  'short_term_debt_issued',
#  'short_term_debt_reduction',
#  'short_term_debt_net',
#  'long_term_debt_issued',
#  'long_term_debt_reduction',
#  'long_term_debt_net',
#  'sale_issuance_of_preferred',
#  'preferred_stock_net',
#  'options_exercised',
#  'cash_from_financing_activities',
#  'net_change_in_cash',
#  'net_cash_beginning_balance',
#  'net_cash_ending_balance',
#  'cash_interest_paid',
#  'cash_taxes_paid',
#  'reported_cash_from_operating_activities',
#  'reported_cash_from_investing_activities',
#  'foreign_exchange_effects',
#  'reported_cash_from_financing_activities',
#  'source_url',
#  'accounting_change',
#  'loss_adjustment',
#  'deferred_policy_acquisition_costs',
#  'reinsurance_receivable',
#  'reinsurance_payable',
#  'unearned_premiums',
#  'insurance_reserves',
#  'investment_securities_gains_losses',
#  'sale_issuance_of_common_preferred',
#  'loans_origination_operating',
#  'loan_loss_provision',
#  'loans_gains_losses',
#  'foreclosed_real_estate',
#  'deposits',
#  'repurchase_retirement_of_preferred',
#  'fiscal_date',
#  'cash_receipts_yoy',
#  'cash_payments_yoy',
#  'net_income_starting_line_yoy',
#  'depreciation_depletion_yoy',
#  'depreciation_yoy',
#  'amortization_yoy',
#  'amortization_of_intangibles_yoy',
#  'deferred_taxes_yoy',
#  'non_cash_items_yoy',
#  'discontinued_operations_yoy',
#  'equity_in_net_earnings_loss_yoy',
#  'unusual_items_yoy',
#  'other_non_cash_items_yoy',
#  'changes_in_working_capital_yoy',
#  'other_assets_liabilities_net_yoy',
#  'other_assets_yoy',
#  'other_liabilities_yoy',
#  'accounts_receivable_yoy',
#  'inventories_yoy',
#  'accounts_payable_yoy',
#  'payable_accrued_yoy',
#  'other_operating_cash_flow_yoy',
#  'cash_from_operating_activities_yoy',
#  'capital_expenditures_yoy',
#  'purchase_acquisition_of_intangibles_yoy',
#  'purchase_of_fixed_assets_yoy',
#  'other_investing_cash_flow_items_total_yoy',
#  'sale_maturity_of_investment_yoy',
#  'purchase_of_investments_yoy',
#  'sale_of_intangible_assets_yoy',
#  'sale_of_business_yoy',
#  'investment_net_yoy',
#  'acquisition_of_business_yoy',
#  'sale_of_fixed_assets_yoy',
#  'intangible_net_yoy',
#  'other_investing_cash_flow_yoy',
#  'cash_from_investing_activities_yoy',
#  'financing_cash_flow_items_yoy',
#  'other_financing_cash_flow_yoy',
#  'total_cash_dividends_paid_yoy',
#  'cash_dividends_paid_common_yoy',
#  'issuance_retirement_of_stock_net_yoy',
#  'sale_issuance_of_common_yoy',
#  'repurchase_retirement_of_common_yoy',
#  'common_stock_net_yoy',
#  'warrants_converted_yoy',
#  'issuance_retirement_of_debt_net_yoy',
#  'short_term_debt_issued_yoy',
#  'short_term_debt_reduction_yoy',
#  'short_term_debt_net_yoy',
#  'long_term_debt_issued_yoy',
#  'long_term_debt_reduction_yoy',
#  'long_term_debt_net_yoy',
#  'sale_issuance_of_preferred_yoy',
#  'preferred_stock_net_yoy',
#  'options_exercised_yoy',
#  'cash_from_financing_activities_yoy',
#  'net_change_in_cash_yoy',
#  'net_cash_beginning_balance_yoy',
#  'net_cash_ending_balance_yoy',
#  'cash_interest_paid_yoy',
#  'cash_taxes_paid_yoy',
#  'foreign_exchange_effects_yoy',
#  'deferred_policy_acquisition_costs_yoy',
#  'reinsurance_receivable_yoy',
#  'reinsurance_payable_yoy',
#  'investment_securities_gains_losses_yoy',
#  'loan_loss_provision_yoy',
#  'loans_gains_losses_yoy',
#  'foreclosed_real_estate_yoy']

# %%
# Get null ratios sorted
null_ratios = df.isnull().mean().sort_values(ascending=False)

# Convert to DataFrame with formatted percentage
summary_df = pd.DataFrame({
    "column": null_ratios.index,
    "null_ratio": (null_ratios * 100).map("{:.2f}%".format)
})

# # Save to CSV
summary_df.to_csv("../../column_percentages/balance_null_ratio_summary.csv", index=False)
summary_df.head()
# Out:
#                                                                           column  \
# insurance_reserves                                            insurance_reserves
# reported_cash_from_operating_activities  reported_cash_from_operating_activities
# repurchase_retirement_of_preferred            repurchase_retirement_of_preferred
# deposits                                                                deposits
# loans_origination_operating                          loans_origination_operating
#
#                                         null_ratio
# insurance_reserves                         100.00%
# reported_cash_from_operating_activities    100.00%
# repurchase_retirement_of_preferred         100.00%
# deposits                                   100.00%
# loans_origination_operating                100.00%

# %%
# desired_columns = [
#     "old_registration_number",
#     "other_current_assets_total",
#     "total_current_assets",
#     "other_current_liabilities_total",
#     "total_current_liabilities",
#     "other_long_term_liabilities",
#     "retained_earnings_accumulated_deficit",
#     "total_equity",
#     "fiscal_date",
#     "registration_number"
# ]
# df = df[[col for col in desired_columns if col in df.columns]]

# %%
df.isnull().sum()
# Out:
# company_name_bursa                           0
# company_name_api                           121
# registration_number                        121
# old_registration_number                    121
# company_id                                   0
#                                           ...
# reinsurance_payable_yoy                   4830
# investment_securities_gains_losses_yoy    4754
# loan_loss_provision_yoy                   4790
# loans_gains_losses_yoy                    4788
# foreclosed_real_estate_yoy                4840
# Length: 159, dtype: int64

# %%
df
# Out:
#                      company_name_bursa                   company_name_api  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 3     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 4     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# ...                                 ...                                ...
# 4838               UCI RESOURCES BERHAD               UCI RESOURCES BERHAD
# 4839       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4840       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4841       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4842       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
#
#      registration_number old_registration_number company_id cash_receipts  \
# 0         201301028701.0               1058531-W       5250      3,058.75
# 1         201301028701.0               1058531-W       5250      4,358.27
# 2         201301028701.0               1058531-W       5250      4,010.94
# 3         201301028701.0               1058531-W       5250      3,041.35
# 4         201301028701.0               1058531-W       5250      2,732.29
# ...                  ...                     ...        ...           ...
# 4838      202001015323.0               1371643-X      03043           NaN
# 4839      201801007506.0               1269520-X      03017           NaN
# 4840      201801007506.0               1269520-X      03017           NaN
# 4841      201801007506.0               1269520-X      03017           NaN
# 4842      201801007506.0               1269520-X      03017           NaN
#
#      cash_payments net_income_starting_line depreciation_depletion  \
# 0        -2,881.78                      NaN                    NaN
# 1        -3,984.39                      NaN                    NaN
# 2        -3,459.32                      NaN                    NaN
# 3        -2,705.03                      NaN                    NaN
# 4        -2,454.78                      NaN                    NaN
# ...            ...                      ...                    ...
# 4838           NaN                     2.26                   1.22
# 4839           NaN                     4.55                   0.99
# 4840           NaN                   -12.35                   1.42
# 4841           NaN                     5.59                   0.89
# 4842           NaN                     9.67                   0.73
#
#      depreciation  ... cash_interest_paid_yoy  cash_taxes_paid_yoy  \
# 0             NaN  ...                 16.71%               55.88%
# 1             NaN  ...                -18.73%              -45.51%
# 2             NaN  ...                -14.89%              -19.42%
# 3             NaN  ...                -28.92%              -43.84%
# 4             NaN  ...               -157.40%              -33.04%
# ...           ...  ...                    ...                  ...
# 4838         1.22  ...                -15.00%              -68.94%
# 4839         0.99  ...                -44.66%              -81.67%
# 4840         1.42  ...                128.89%              -72.48%
# 4841         0.89  ...                 57.89%              938.10%
# 4842         0.73  ...                 29.55%              -94.41%
#
#      foreign_exchange_effects_yoy deferred_policy_acquisition_costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                          NaN                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                        0.00%                                   NaN
# 4842                          NaN                                   NaN
#
#      reinsurance_receivable_yoy reinsurance_payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      investment_securities_gains_losses_yoy loan_loss_provision_yoy  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 4838                                    NaN                     NaN
# 4839                                    NaN                     NaN
# 4840                                    NaN                     NaN
# 4841                                    NaN                     NaN
# 4842                                    NaN                     NaN
#
#      loans_gains_losses_yoy foreclosed_real_estate_yoy
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 4838                    NaN                        NaN
# 4839                    NaN                        NaN
# 4840                    NaN                        NaN
# 4841                    NaN                        NaN
# 4842                    NaN                        NaN
#
# [4843 rows x 159 columns]

# %%
df = df.dropna(subset=["registration_number"])

# %%
df['registration_number'].nunique()
# Out:
# 1007

# %%
df.isnull().sum()
# Out:
# company_name_bursa                           0
# company_name_api                             0
# registration_number                          0
# old_registration_number                      0
# company_id                                   0
#                                           ...
# reinsurance_payable_yoy                   4709
# investment_securities_gains_losses_yoy    4638
# loan_loss_provision_yoy                   4672
# loans_gains_losses_yoy                    4672
# foreclosed_real_estate_yoy                4719
# Length: 159, dtype: int64

# %%
df
# Out:
#                      company_name_bursa                   company_name_api  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 3     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 4     7-ELEVEN MALAYSIA HOLDINGS BERHAD  7-ELEVEN MALAYSIA HOLDINGS BERHAD
# ...                                 ...                                ...
# 4838               UCI RESOURCES BERHAD               UCI RESOURCES BERHAD
# 4839       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4840       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4841       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
# 4842       UNI WALL APS HOLDINGS BERHAD       UNI WALL APS HOLDINGS BERHAD
#
#      registration_number old_registration_number company_id cash_receipts  \
# 0         201301028701.0               1058531-W       5250      3,058.75
# 1         201301028701.0               1058531-W       5250      4,358.27
# 2         201301028701.0               1058531-W       5250      4,010.94
# 3         201301028701.0               1058531-W       5250      3,041.35
# 4         201301028701.0               1058531-W       5250      2,732.29
# ...                  ...                     ...        ...           ...
# 4838      202001015323.0               1371643-X      03043           NaN
# 4839      201801007506.0               1269520-X      03017           NaN
# 4840      201801007506.0               1269520-X      03017           NaN
# 4841      201801007506.0               1269520-X      03017           NaN
# 4842      201801007506.0               1269520-X      03017           NaN
#
#      cash_payments net_income_starting_line depreciation_depletion  \
# 0        -2,881.78                      NaN                    NaN
# 1        -3,984.39                      NaN                    NaN
# 2        -3,459.32                      NaN                    NaN
# 3        -2,705.03                      NaN                    NaN
# 4        -2,454.78                      NaN                    NaN
# ...            ...                      ...                    ...
# 4838           NaN                     2.26                   1.22
# 4839           NaN                     4.55                   0.99
# 4840           NaN                   -12.35                   1.42
# 4841           NaN                     5.59                   0.89
# 4842           NaN                     9.67                   0.73
#
#      depreciation  ... cash_interest_paid_yoy  cash_taxes_paid_yoy  \
# 0             NaN  ...                 16.71%               55.88%
# 1             NaN  ...                -18.73%              -45.51%
# 2             NaN  ...                -14.89%              -19.42%
# 3             NaN  ...                -28.92%              -43.84%
# 4             NaN  ...               -157.40%              -33.04%
# ...           ...  ...                    ...                  ...
# 4838         1.22  ...                -15.00%              -68.94%
# 4839         0.99  ...                -44.66%              -81.67%
# 4840         1.42  ...                128.89%              -72.48%
# 4841         0.89  ...                 57.89%              938.10%
# 4842         0.73  ...                 29.55%              -94.41%
#
#      foreign_exchange_effects_yoy deferred_policy_acquisition_costs_yoy  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 4838                          NaN                                   NaN
# 4839                        0.00%                                   NaN
# 4840                        0.00%                                   NaN
# 4841                        0.00%                                   NaN
# 4842                          NaN                                   NaN
#
#      reinsurance_receivable_yoy reinsurance_payable_yoy  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 4838                        NaN                     NaN
# 4839                        NaN                     NaN
# 4840                        NaN                     NaN
# 4841                        NaN                     NaN
# 4842                        NaN                     NaN
#
#      investment_securities_gains_losses_yoy loan_loss_provision_yoy  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 4838                                    NaN                     NaN
# 4839                                    NaN                     NaN
# 4840                                    NaN                     NaN
# 4841                                    NaN                     NaN
# 4842                                    NaN                     NaN
#
#      loans_gains_losses_yoy foreclosed_real_estate_yoy
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 4838                    NaN                        NaN
# 4839                    NaN                        NaN
# 4840                    NaN                        NaN
# 4841                    NaN                        NaN
# 4842                    NaN                        NaN
#
# [4722 rows x 159 columns]

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# ── Load environment variables ──
load_dotenv()

# ── Read DB credentials ──
user = os.getenv("PG_USER")
password = os.getenv("PG_PASSWORD")
host = os.getenv("PG_HOST")
port = os.getenv("PG_PORT")
database = os.getenv("PG_DATABASE")

# ── Create connection string ──
connection_url = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_url)

# ── Your DataFrame ──
df = df.copy()

# ── Push to DB ──
df.to_sql("public_complete_cash_flow", engine, schema="public", index=False, if_exists="replace")

print("✅ Uploaded to 'public_complete_cash_flow' with normalized column names.")
# Out:
# ✅ Uploaded to 'public_complete_cash_flow' with normalized column names.
