# %%
import pandas as pd

# %%
csv = pd.read_csv("../combined_top10.csv",keep_default_na=True,na_values=["None", "none", "NaN", "-"],low_memory=False,dtype={"company_id": str})
csv["company_id"] = csv["company_id"].astype(str)

# %%
df = csv
bad_ids = df[~df["company_id"].str.fullmatch(r"\d{4}")]
print("Bad company_ids:")
print(bad_ids['company_id'])
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 2       03050
# 3       03050
# 4       03050
# 5       03050
# 6       03050
# 867     03008
# 918     03053
# 919     03053
# 920     03053
# 1061    03021
# 1062    03021
# 1523    03022
# 1534    03041
# 1535    03041
# 1596    03046
# 1597    03046
# Name: company_id, dtype: object

# %%
# Ensure company_id is string
csv["company_id"] = csv["company_id"].astype(str)

# Detect bad IDs (not exactly 4 digits)
bad_mask = ~csv["company_id"].str.fullmatch(r"\d{4}")

# Print them
print("Bad company_ids:")
print(csv.loc[bad_mask, "company_id"])

# Fix only the bad ones
csv.loc[bad_mask, "company_id"] = csv.loc[bad_mask, "company_id"].str.zfill(4)
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 2       03050
# 3       03050
# 4       03050
# 5       03050
# 6       03050
# 867     03008
# 918     03053
# 919     03053
# 920     03053
# 1061    03021
# 1062    03021
# 1523    03022
# 1534    03041
# 1535    03041
# 1596    03046
# 1597    03046
# Name: company_id, dtype: object

# %%
# Ensure company_id is string type
csv["company_id"] = csv["company_id"].astype(str)

# Find malformed IDs that are not 4-digit strings
bad_ids = csv[~csv["company_id"].str.fullmatch(r"\d{4}")]

# Report bad IDs
print("Bad company_ids:")
print(bad_ids["company_id"])
# Out:
# Bad company_ids:
# 0       03050
# 1       03050
# 2       03050
# 3       03050
# 4       03050
# 5       03050
# 6       03050
# 867     03008
# 918     03053
# 919     03053
# 920     03053
# 1061    03021
# 1062    03021
# 1523    03022
# 1534    03041
# 1535    03041
# 1596    03046
# 1597    03046
# Name: company_id, dtype: object

# %%
csv["company_id"].nunique()
# Out:
# 170

# %%
df = csv

# %%
merged = df

# %%
len(merged.columns)
# Out:
# 11

# %%
merged
# Out:
#      company_id                                        company_url  \
# 0         03050  https://my.bursamalaysia.com/stock-details?sto...
# 1         03050  https://my.bursamalaysia.com/stock-details?sto...
# 2         03050  https://my.bursamalaysia.com/stock-details?sto...
# 3         03050  https://my.bursamalaysia.com/stock-details?sto...
# 4         03050  https://my.bursamalaysia.com/stock-details?sto...
# ...         ...                                                ...
# 1643       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1644       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1645       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1646       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1647       0335  https://my.bursamalaysia.com/stock-details?sto...
#
#                                  Investor Name Ownership %  \
# 0                           Kong (Chiong Miew)      43.82%
# 1                            Kong (Chiong Ung)      24.52%
# 2                             Bene Sky Sdn Bhd       8.12%
# 3                               Lee (Yew Chen)       3.28%
# 4                           Chieng (Mee Chang)       2.16%
# ...                                        ...         ...
# 1643               Statens Pensjonsfond Utland       2.35%
# 1644  Norges Bank Investment Management (NBIM)       2.35%
# 1645                Kontrak Kosmomaz Sdn. Bhd.       2.28%
# 1646                   Able Wealth Assets Ltd.       2.26%
# 1647                             Loh (Vincent)       0.02%
#
#      Position (M Shares) Position Change (M) Position Change (M) %  \
# 0                 102.52               -2.00                   NaN
# 1                  57.37              -10.00                   NaN
# 2                  18.99                0.00                   NaN
# 3                   7.66               +0.15                +1.93%
# 4                   5.06               +5.00               +98.81%
# ...                  ...                 ...                   ...
# 1643               22.96              +22.96              +100.00%
# 1644               22.96              +22.96              +100.00%
# 1645               22.33              +22.33              +100.00%
# 1646               22.11              +22.11              +100.00%
# 1647                0.20               +0.20              +100.00%
#
#       Position Value Change (M) Value (M USD)  Filing Date  \
# 0                           NaN         27.29          NaN
# 1                           NaN         16.34          NaN
# 2                           NaN          5.30          NaN
# 3                          0.04          2.14  28-Feb-2025
# 4                          1.42          1.44  22-Apr-2025
# ...                         ...           ...          ...
# 1643                       1.03          1.03  31-Dec-2024
# 1644                       1.03          1.03  31-Dec-2024
# 1645                       1.00          1.00  18-Dec-2024
# 1646                       0.99          0.99  18-Dec-2024
# 1647                       0.01          0.01  18-Dec-2024
#
#                      Filing Source
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                 Malaysia Insider
# 4     Other Substantial/Declarable
# ...                            ...
# 1643                            MF
# 1644                 Aggregate MFs
# 1645  Other Substantial/Declarable
# 1646  Other Substantial/Declarable
# 1647              Malaysia Insider
#
# [1648 rows x 11 columns]

# %%
bursa_registration = pd.read_csv("../matched_companies_from_ssm.csv",dtype={"company_id": str,"companyNo": str})
bursa_registration["companyNo"] = (
    bursa_registration["companyNo"]
    .astype(str)
    .str.replace(r"\.0$", "", regex=True)
    .str.strip()
)
bursa_registration.head()
# Out:
#                            company_name                               name_db  \
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD     7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1  99 SPEED MART RETAIL HOLDINGS BERHAD  99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                         A-RANK BERHAD           A-RANK ASSOCIATES SDN. BHD.
# 3                    ABLE GLOBAL BERHAD          ABLE GLOBAL (MM2H) SDN. BHD.
# 4                      ABLEGROUP BERHAD                      ABLEGROUP BERHAD
#
#         companyNo oldCompanyNo company_type
# 0  201301028701.0    1058531-W      Company
# 1  202301017784.0    1511706-T      Company
# 2  199701029773.0     445272-P      Company
# 3  199501013751.0     342952-P      Company
# 4  200401015685.0     654188-H      Company

# %%
company_id = pd.read_csv("../../../list_bursa_ids/bursa_company_list.csv", dtype={"company_id": str})
company_id["company_id"] = company_id["company_id"].str.strip().str.zfill(4)

# %%
merge = pd.merge(bursa_registration,company_id,on="company_name",how="inner")
merge
# Out:
#                               company_name  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                                    name_db       companyNo oldCompanyNo  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD  201301028701.0    1058531-W
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD  202301017784.0    1511706-T
# 2              A-RANK ASSOCIATES SDN. BHD.  199701029773.0     445272-P
# 3             ABLE GLOBAL (MM2H) SDN. BHD.  199501013751.0     342952-P
# 4                         ABLEGROUP BERHAD  200401015685.0     654188-H
# ...                                    ...             ...          ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD  202201036425.0    1482122-A
# 1074                 TP TEC HOLDING BERHAD  202401020280.0    1566129-V
# 1075                           TSIC BERHAD  202301036647.0    1530570-U
# 1076                  UCI RESOURCES BERHAD  202001015323.0    1371643-X
# 1077          UNI WALL APS HOLDINGS BERHAD  201801007506.0    1269520-X
#
#      company_type company_id
# 0         Company       5250
# 1         Company       5326
# 2         Company       7214
# 3         Company       7167
# 4         Company       7086
# ...           ...        ...
# 1073      Company      03058
# 1074      Company      03061
# 1075      Company      03062
# 1076      Company      03043
# 1077      Company      03017
#
# [1078 rows x 6 columns]

# %%
len(merge["company_id"].drop_duplicates())
# Out:
# 1078

# %%
merge_copy = merge.copy()

# %%
merge = merge.drop(columns="company_type")
merge = merge.rename(columns={
    "company_name": "company_name_bursa",
    "name_db": "company_name_api",
    "companyNo": "registration_number",
    "oldCompanyNo": "old_registration_number"
})
# merge.to_csv("bursa_company_registra.csv", index=False)

# %%
merge
# Out:
#                         company_name_bursa  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                           company_name_api registration_number  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD      201301028701.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2              A-RANK ASSOCIATES SDN. BHD.      199701029773.0
# 3             ABLE GLOBAL (MM2H) SDN. BHD.      199501013751.0
# 4                         ABLEGROUP BERHAD      200401015685.0
# ...                                    ...                 ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD      202201036425.0
# 1074                 TP TEC HOLDING BERHAD      202401020280.0
# 1075                           TSIC BERHAD      202301036647.0
# 1076                  UCI RESOURCES BERHAD      202001015323.0
# 1077          UNI WALL APS HOLDINGS BERHAD      201801007506.0
#
#      old_registration_number company_id
# 0                  1058531-W       5250
# 1                  1511706-T       5326
# 2                   445272-P       7214
# 3                   342952-P       7167
# 4                   654188-H       7086
# ...                      ...        ...
# 1073               1482122-A      03058
# 1074               1566129-V      03061
# 1075               1530570-U      03062
# 1076               1371643-X      03043
# 1077               1269520-X      03017
#
# [1078 rows x 5 columns]

# %%
merged
# Out:
#      company_id                                        company_url  \
# 0         03050  https://my.bursamalaysia.com/stock-details?sto...
# 1         03050  https://my.bursamalaysia.com/stock-details?sto...
# 2         03050  https://my.bursamalaysia.com/stock-details?sto...
# 3         03050  https://my.bursamalaysia.com/stock-details?sto...
# 4         03050  https://my.bursamalaysia.com/stock-details?sto...
# ...         ...                                                ...
# 1643       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1644       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1645       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1646       0335  https://my.bursamalaysia.com/stock-details?sto...
# 1647       0335  https://my.bursamalaysia.com/stock-details?sto...
#
#                                  Investor Name Ownership %  \
# 0                           Kong (Chiong Miew)      43.82%
# 1                            Kong (Chiong Ung)      24.52%
# 2                             Bene Sky Sdn Bhd       8.12%
# 3                               Lee (Yew Chen)       3.28%
# 4                           Chieng (Mee Chang)       2.16%
# ...                                        ...         ...
# 1643               Statens Pensjonsfond Utland       2.35%
# 1644  Norges Bank Investment Management (NBIM)       2.35%
# 1645                Kontrak Kosmomaz Sdn. Bhd.       2.28%
# 1646                   Able Wealth Assets Ltd.       2.26%
# 1647                             Loh (Vincent)       0.02%
#
#      Position (M Shares) Position Change (M) Position Change (M) %  \
# 0                 102.52               -2.00                   NaN
# 1                  57.37              -10.00                   NaN
# 2                  18.99                0.00                   NaN
# 3                   7.66               +0.15                +1.93%
# 4                   5.06               +5.00               +98.81%
# ...                  ...                 ...                   ...
# 1643               22.96              +22.96              +100.00%
# 1644               22.96              +22.96              +100.00%
# 1645               22.33              +22.33              +100.00%
# 1646               22.11              +22.11              +100.00%
# 1647                0.20               +0.20              +100.00%
#
#       Position Value Change (M) Value (M USD)  Filing Date  \
# 0                           NaN         27.29          NaN
# 1                           NaN         16.34          NaN
# 2                           NaN          5.30          NaN
# 3                          0.04          2.14  28-Feb-2025
# 4                          1.42          1.44  22-Apr-2025
# ...                         ...           ...          ...
# 1643                       1.03          1.03  31-Dec-2024
# 1644                       1.03          1.03  31-Dec-2024
# 1645                       1.00          1.00  18-Dec-2024
# 1646                       0.99          0.99  18-Dec-2024
# 1647                       0.01          0.01  18-Dec-2024
#
#                      Filing Source
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                 Malaysia Insider
# 4     Other Substantial/Declarable
# ...                            ...
# 1643                            MF
# 1644                 Aggregate MFs
# 1645  Other Substantial/Declarable
# 1646  Other Substantial/Declarable
# 1647              Malaysia Insider
#
# [1648 rows x 11 columns]

# %%
merged["company_id"].nunique()
# Out:
# 170

# %%
merge["company_id"] = merge["company_id"].str.strip()
merged["company_id"] = merged["company_id"].str.strip()

# %%
merge["company_id"] = merge["company_id"].astype(str)
merged["company_id"] = merged["company_id"].astype(str)
final_merge = merge.merge(merged, on="company_id", how="inner")

# %%
final_merge['company_id'].nunique()
# Out:
# 170

# %%
merge
# Out:
#                         company_name_bursa  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2                            A-RANK BERHAD
# 3                       ABLE GLOBAL BERHAD
# 4                         ABLEGROUP BERHAD
# ...                                    ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD
# 1074                 TP TEC HOLDING BERHAD
# 1075                           TSIC BERHAD
# 1076                  UCI RESOURCES BERHAD
# 1077          UNI WALL APS HOLDINGS BERHAD
#
#                           company_name_api registration_number  \
# 0        7-ELEVEN MALAYSIA HOLDINGS BERHAD      201301028701.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2              A-RANK ASSOCIATES SDN. BHD.      199701029773.0
# 3             ABLE GLOBAL (MM2H) SDN. BHD.      199501013751.0
# 4                         ABLEGROUP BERHAD      200401015685.0
# ...                                    ...                 ...
# 1073         TOTAL DYNAMIC HOLDINGS BERHAD      202201036425.0
# 1074                 TP TEC HOLDING BERHAD      202401020280.0
# 1075                           TSIC BERHAD      202301036647.0
# 1076                  UCI RESOURCES BERHAD      202001015323.0
# 1077          UNI WALL APS HOLDINGS BERHAD      201801007506.0
#
#      old_registration_number company_id
# 0                  1058531-W       5250
# 1                  1511706-T       5326
# 2                   445272-P       7214
# 3                   342952-P       7167
# 4                   654188-H       7086
# ...                      ...        ...
# 1073               1482122-A      03058
# 1074               1566129-V      03061
# 1075               1530570-U      03062
# 1076               1371643-X      03043
# 1077               1269520-X      03017
#
# [1078 rows x 5 columns]

# %%
(final_merge.isnull().mean() * 100).sort_values(ascending=False).to_frame("missing_%").style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_39beb_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_39beb_row1_col0 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_39beb_row2_col0 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_39beb_row3_col0 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_39beb_row4_col0, #T_39beb_row5_col0, #T_39beb_row6_col0 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_39beb_row7_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_39beb_row8_col0, #T_39beb_row9_col0, #T_39beb_row10_col0, #T_39beb_row11_col0, #T_39beb_row12_col0, #T_39beb_row13_col0, #T_39beb_row14_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_39beb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39beb_level0_col0" class="col_heading level0 col0" >missing_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39beb_level0_row0" class="row_heading level0 row0" >Position Change (M) %</th>
#       <td id="T_39beb_row0_col0" class="data row0 col0" >16.322816</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row1" class="row_heading level0 row1" >Position Value Change (M)</th>
#       <td id="T_39beb_row1_col0" class="data row1 col0" >15.898058</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row2" class="row_heading level0 row2" >Filing Date</th>
#       <td id="T_39beb_row2_col0" class="data row2 col0" >14.623786</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row3" class="row_heading level0 row3" >Filing Source</th>
#       <td id="T_39beb_row3_col0" class="data row3 col0" >14.259709</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row4" class="row_heading level0 row4" >company_name_api</th>
#       <td id="T_39beb_row4_col0" class="data row4 col0" >1.820388</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row5" class="row_heading level0 row5" >registration_number</th>
#       <td id="T_39beb_row5_col0" class="data row5 col0" >1.820388</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row6" class="row_heading level0 row6" >old_registration_number</th>
#       <td id="T_39beb_row6_col0" class="data row6 col0" >1.820388</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row7" class="row_heading level0 row7" >Investor Name</th>
#       <td id="T_39beb_row7_col0" class="data row7 col0" >0.121359</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row8" class="row_heading level0 row8" >company_name_bursa</th>
#       <td id="T_39beb_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row9" class="row_heading level0 row9" >company_id</th>
#       <td id="T_39beb_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row10" class="row_heading level0 row10" >company_url</th>
#       <td id="T_39beb_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row11" class="row_heading level0 row11" >Ownership %</th>
#       <td id="T_39beb_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row12" class="row_heading level0 row12" >Position (M Shares)</th>
#       <td id="T_39beb_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row13" class="row_heading level0 row13" >Position Change (M)</th>
#       <td id="T_39beb_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39beb_level0_row14" class="row_heading level0 row14" >Value (M USD)</th>
#       <td id="T_39beb_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df=final_merge

# %%
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 1643                 SUNMOW HOLDING BERHAD
# 1644                 SUNMOW HOLDING BERHAD
# 1645                 SUNMOW HOLDING BERHAD
# 1646                 SUNMOW HOLDING BERHAD
# 1647                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 1643                 SUNMOW HOLDING BERHAD      202001024626.0
# 1644                 SUNMOW HOLDING BERHAD      202001024626.0
# 1645                 SUNMOW HOLDING BERHAD      202001024626.0
# 1646                 SUNMOW HOLDING BERHAD      202001024626.0
# 1647                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 1643               1380946-V      03050
# 1644               1380946-V      03050
# 1645               1380946-V      03050
# 1646               1380946-V      03050
# 1647               1380946-V      03050
#
#                                             company_url  \
# 0     https://my.bursamalaysia.com/stock-details?sto...
# 1     https://my.bursamalaysia.com/stock-details?sto...
# 2     https://my.bursamalaysia.com/stock-details?sto...
# 3     https://my.bursamalaysia.com/stock-details?sto...
# 4     https://my.bursamalaysia.com/stock-details?sto...
# ...                                                 ...
# 1643  https://my.bursamalaysia.com/stock-details?sto...
# 1644  https://my.bursamalaysia.com/stock-details?sto...
# 1645  https://my.bursamalaysia.com/stock-details?sto...
# 1646  https://my.bursamalaysia.com/stock-details?sto...
# 1647  https://my.bursamalaysia.com/stock-details?sto...
#
#                                  Investor Name Ownership %  \
# 0                              Lee (Thiam Wah)      79.68%
# 1                               Ng (Lee Tieng)       3.32%
# 2                     The Vanguard Group, Inc.       0.47%
# 3                  Statens Pensjonsfond Utland       0.46%
# 4     Norges Bank Investment Management (NBIM)       0.46%
# ...                                        ...         ...
# 1643                          Bene Sky Sdn Bhd       8.12%
# 1644                            Lee (Yew Chen)       3.28%
# 1645                        Chieng (Mee Chang)       2.16%
# 1646                           Kong (Chung Xu)       2.14%
# 1647                Family of Kong Chiong Miew       0.13%
#
#      Position (M Shares) Position Change (M) Position Change (M) %  \
# 0               6,693.12           +6,693.12                   NaN
# 1                 278.88             +278.88                   NaN
# 2                  39.80               +0.83                +2.08%
# 3                  38.71              +38.71              +100.00%
# 4                  38.71              +38.71              +100.00%
# ...                  ...                 ...                   ...
# 1643               18.99                0.00                   NaN
# 1644                7.66               +0.15                +1.93%
# 1645                5.06               +5.00               +98.81%
# 1646                5.00               +5.00              +100.00%
# 1647                0.30                0.00                 0.00%
#
#       Position Value Change (M) Value (M USD)  Filing Date  \
# 0                           NaN      3,621.85          NaN
# 1                           NaN        150.91  09-Sep-2024
# 2                          0.43         20.71  30-Apr-2025
# 3                         21.44         21.44  31-Dec-2024
# 4                         21.44         21.44  31-Dec-2024
# ...                         ...           ...          ...
# 1643                        NaN          5.30          NaN
# 1644                       0.04          2.14  28-Feb-2025
# 1645                       1.42          1.44  22-Apr-2025
# 1646                       1.42          1.42  22-Apr-2025
# 1647                       0.00          0.08  25-Jul-2023
#
#                      Filing Source
# 0                              NaN
# 1                 Malaysia Insider
# 2                    Aggregate MFs
# 3                               MF
# 4                    Aggregate MFs
# ...                            ...
# 1643                           NaN
# 1644              Malaysia Insider
# 1645  Other Substantial/Declarable
# 1646  Other Substantial/Declarable
# 1647  Other Substantial/Declarable
#
# [1648 rows x 15 columns]

# %%
# ── Your DataFrame ──
df = df.copy()
df.columns = df.columns.str.replace("-", " ").str.strip().str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 1643                 SUNMOW HOLDING BERHAD
# 1644                 SUNMOW HOLDING BERHAD
# 1645                 SUNMOW HOLDING BERHAD
# 1646                 SUNMOW HOLDING BERHAD
# 1647                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 1643                 SUNMOW HOLDING BERHAD      202001024626.0
# 1644                 SUNMOW HOLDING BERHAD      202001024626.0
# 1645                 SUNMOW HOLDING BERHAD      202001024626.0
# 1646                 SUNMOW HOLDING BERHAD      202001024626.0
# 1647                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 1643               1380946-V      03050
# 1644               1380946-V      03050
# 1645               1380946-V      03050
# 1646               1380946-V      03050
# 1647               1380946-V      03050
#
#                                             company_url  \
# 0     https://my.bursamalaysia.com/stock-details?sto...
# 1     https://my.bursamalaysia.com/stock-details?sto...
# 2     https://my.bursamalaysia.com/stock-details?sto...
# 3     https://my.bursamalaysia.com/stock-details?sto...
# 4     https://my.bursamalaysia.com/stock-details?sto...
# ...                                                 ...
# 1643  https://my.bursamalaysia.com/stock-details?sto...
# 1644  https://my.bursamalaysia.com/stock-details?sto...
# 1645  https://my.bursamalaysia.com/stock-details?sto...
# 1646  https://my.bursamalaysia.com/stock-details?sto...
# 1647  https://my.bursamalaysia.com/stock-details?sto...
#
#                                  investor_name ownership_%  \
# 0                              Lee (Thiam Wah)      79.68%
# 1                               Ng (Lee Tieng)       3.32%
# 2                     The Vanguard Group, Inc.       0.47%
# 3                  Statens Pensjonsfond Utland       0.46%
# 4     Norges Bank Investment Management (NBIM)       0.46%
# ...                                        ...         ...
# 1643                          Bene Sky Sdn Bhd       8.12%
# 1644                            Lee (Yew Chen)       3.28%
# 1645                        Chieng (Mee Chang)       2.16%
# 1646                           Kong (Chung Xu)       2.14%
# 1647                Family of Kong Chiong Miew       0.13%
#
#      position_(m_shares) position_change_(m) position_change_(m)_%  \
# 0               6,693.12           +6,693.12                   NaN
# 1                 278.88             +278.88                   NaN
# 2                  39.80               +0.83                +2.08%
# 3                  38.71              +38.71              +100.00%
# 4                  38.71              +38.71              +100.00%
# ...                  ...                 ...                   ...
# 1643               18.99                0.00                   NaN
# 1644                7.66               +0.15                +1.93%
# 1645                5.06               +5.00               +98.81%
# 1646                5.00               +5.00              +100.00%
# 1647                0.30                0.00                 0.00%
#
#       position_value_change_(m) value_(m_usd)  filing_date  \
# 0                           NaN      3,621.85          NaN
# 1                           NaN        150.91  09-Sep-2024
# 2                          0.43         20.71  30-Apr-2025
# 3                         21.44         21.44  31-Dec-2024
# 4                         21.44         21.44  31-Dec-2024
# ...                         ...           ...          ...
# 1643                        NaN          5.30          NaN
# 1644                       0.04          2.14  28-Feb-2025
# 1645                       1.42          1.44  22-Apr-2025
# 1646                       1.42          1.42  22-Apr-2025
# 1647                       0.00          0.08  25-Jul-2023
#
#                      filing_source
# 0                              NaN
# 1                 Malaysia Insider
# 2                    Aggregate MFs
# 3                               MF
# 4                    Aggregate MFs
# ...                            ...
# 1643                           NaN
# 1644              Malaysia Insider
# 1645  Other Substantial/Declarable
# 1646  Other Substantial/Declarable
# 1647  Other Substantial/Declarable
#
# [1648 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['company_name_bursa', 'company_name_api', 'registration_number',
#        'old_registration_number', 'company_id', 'company_url', 'investor_name',
#        'ownership_%', 'position_(m_shares)', 'position_change_(m)',
#        'position_change_(m)_%', 'position_value_change_(m)', 'value_(m_usd)',
#        'filing_date', 'filing_source'],
#       dtype='object')

# %%
import re
df.columns = (
    df.columns
    .str.replace("-", " ", regex=False)        # Replace hyphens with spaces
    .str.replace("/", " ", regex=False) 
    .str.strip()
    .str.lower()
    .str.replace(r"[^\w\s]", "", regex=True)   # Remove non-word characters like . , &
    .str.replace(r"\s+", "_", regex=True)      # Convert spaces to single underscore
    .str.replace(r"_+", "_", regex=True)       # Collapse multiple underscores to one
)

# %%
df
# Out:
#                         company_name_bursa  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD
# ...                                    ...
# 1643                 SUNMOW HOLDING BERHAD
# 1644                 SUNMOW HOLDING BERHAD
# 1645                 SUNMOW HOLDING BERHAD
# 1646                 SUNMOW HOLDING BERHAD
# 1647                 SUNMOW HOLDING BERHAD
#
#                           company_name_api registration_number  \
# 0     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 1     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 2     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 3     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# 4     99 SPEED MART RETAIL HOLDINGS BERHAD      202301017784.0
# ...                                    ...                 ...
# 1643                 SUNMOW HOLDING BERHAD      202001024626.0
# 1644                 SUNMOW HOLDING BERHAD      202001024626.0
# 1645                 SUNMOW HOLDING BERHAD      202001024626.0
# 1646                 SUNMOW HOLDING BERHAD      202001024626.0
# 1647                 SUNMOW HOLDING BERHAD      202001024626.0
#
#      old_registration_number company_id  \
# 0                  1511706-T       5326
# 1                  1511706-T       5326
# 2                  1511706-T       5326
# 3                  1511706-T       5326
# 4                  1511706-T       5326
# ...                      ...        ...
# 1643               1380946-V      03050
# 1644               1380946-V      03050
# 1645               1380946-V      03050
# 1646               1380946-V      03050
# 1647               1380946-V      03050
#
#                                             company_url  \
# 0     https://my.bursamalaysia.com/stock-details?sto...
# 1     https://my.bursamalaysia.com/stock-details?sto...
# 2     https://my.bursamalaysia.com/stock-details?sto...
# 3     https://my.bursamalaysia.com/stock-details?sto...
# 4     https://my.bursamalaysia.com/stock-details?sto...
# ...                                                 ...
# 1643  https://my.bursamalaysia.com/stock-details?sto...
# 1644  https://my.bursamalaysia.com/stock-details?sto...
# 1645  https://my.bursamalaysia.com/stock-details?sto...
# 1646  https://my.bursamalaysia.com/stock-details?sto...
# 1647  https://my.bursamalaysia.com/stock-details?sto...
#
#                                  investor_name ownership_ position_m_shares  \
# 0                              Lee (Thiam Wah)     79.68%          6,693.12
# 1                               Ng (Lee Tieng)      3.32%            278.88
# 2                     The Vanguard Group, Inc.      0.47%             39.80
# 3                  Statens Pensjonsfond Utland      0.46%             38.71
# 4     Norges Bank Investment Management (NBIM)      0.46%             38.71
# ...                                        ...        ...               ...
# 1643                          Bene Sky Sdn Bhd      8.12%             18.99
# 1644                            Lee (Yew Chen)      3.28%              7.66
# 1645                        Chieng (Mee Chang)      2.16%              5.06
# 1646                           Kong (Chung Xu)      2.14%              5.00
# 1647                Family of Kong Chiong Miew      0.13%              0.30
#
#      position_change_m position_change_m_  position_value_change_m  \
# 0            +6,693.12                NaN                      NaN
# 1              +278.88                NaN                      NaN
# 2                +0.83             +2.08%                     0.43
# 3               +38.71           +100.00%                    21.44
# 4               +38.71           +100.00%                    21.44
# ...                ...                ...                      ...
# 1643              0.00                NaN                      NaN
# 1644             +0.15             +1.93%                     0.04
# 1645             +5.00            +98.81%                     1.42
# 1646             +5.00           +100.00%                     1.42
# 1647              0.00              0.00%                     0.00
#
#      value_m_usd  filing_date                 filing_source
# 0       3,621.85          NaN                           NaN
# 1         150.91  09-Sep-2024              Malaysia Insider
# 2          20.71  30-Apr-2025                 Aggregate MFs
# 3          21.44  31-Dec-2024                            MF
# 4          21.44  31-Dec-2024                 Aggregate MFs
# ...          ...          ...                           ...
# 1643        5.30          NaN                           NaN
# 1644        2.14  28-Feb-2025              Malaysia Insider
# 1645        1.44  22-Apr-2025  Other Substantial/Declarable
# 1646        1.42  22-Apr-2025  Other Substantial/Declarable
# 1647        0.08  25-Jul-2023  Other Substantial/Declarable
#
# [1648 rows x 15 columns]

# %%
df.columns.tolist()
# Out:
# ['company_name_bursa',
#  'company_name_api',
#  'registration_number',
#  'old_registration_number',
#  'company_id',
#  'company_url',
#  'investor_name',
#  'ownership_',
#  'position_m_shares',
#  'position_change_m',
#  'position_change_m_',
#  'position_value_change_m',
#  'value_m_usd',
#  'filing_date',
#  'filing_source']

# %%
# Check for duplicate column names
duplicates = df.columns[df.columns.duplicated()]
print("Duplicate columns:", duplicates.tolist())
df = df.loc[:, ~df.columns.duplicated()]
# Out:
# Duplicate columns: []

# %%
# Get null ratios sorted
null_ratios = df.isnull().mean().sort_values(ascending=False)

# Convert to DataFrame with formatted percentage
summary_df = pd.DataFrame({
    "column": null_ratios.index,
    "null_ratio": (null_ratios * 100).map("{:.2f}%".format)
})

# Save to CSV
# summary_df.to_csv("/insider_null_ratio_summary.csv", index=False)
summary_df.head()
# Out:
#                                           column null_ratio
# position_change_m_            position_change_m_     16.32%
# position_value_change_m  position_value_change_m     15.90%
# filing_date                          filing_date     14.62%
# filing_source                      filing_source     14.26%
# company_name_api                company_name_api      1.82%

# %%
len(df["registration_number"].drop_duplicates())
# Out:
# 168

# %%
df = df.dropna(subset=["registration_number"])

# %%
df['registration_number'].nunique()
# Out:
# 167

# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

# ── Load environment variables ──
load_dotenv()

# ── Read DB credentials ──
user = os.getenv("PG_USER")
password = os.getenv("PG_PASSWORD")
host = os.getenv("PG_HOST")
port = os.getenv("PG_PORT")
database = os.getenv("PG_DATABASE")

# ── Create connection string ──
connection_url = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_url)

# ── Your DataFrame ──
df = df.copy()

# ── Push to DB ──
df.to_sql("public_complete_top_10_investors", engine, schema="public", index=False, if_exists="replace")

print("✅ Uploaded to 'public_complete_top_10_investors' with normalized column names.")
# Out:
# ✅ Uploaded to 'public_complete_top_10_investors' with normalized column names.
